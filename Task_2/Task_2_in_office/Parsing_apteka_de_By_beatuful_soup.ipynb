# %% [markdown]
# <a href="https://colab.research.google.com/github/VasylDvorakDS/Collection_data/blob/master/Parsing_apteka_de_By_beatuful_soup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Парсинг HTML. BeautifulSoup.

# %% [markdown]
# ### Скрейпинг и парсинг данных одной страницы.

# %%
# Импорт необходимых библиотек
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# Путь к странице с данным
website = "https://apteka.de/online-shop/allergie-heuschnupfen"

# %%
# GET-запрос к серверу
page = requests.get(website)

# %%
# Проверка статуса ответа сервера
page.status_code
# Out:
# 200

# %%
type(page.text)
# Out:
# str

# %%
type(page.content)
# Out:
# bytes

# %%
# Парсинг данных
soup = BeautifulSoup(page.content, 'html.parser')

# %%
page.text
# Out:
# '<!DOCTYPE html>\n\n<html lang="ru" >\n<head>\n    <script>\n    let cookiesAccepted = document.cookie.indexOf("cookie-policy-accepted") != -1;\n    let month = new Array("Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct", "Nov", "Dec");\n    let days = new Array("Sun","Mon","Tue","Wed","Thu","Fri","Sat");\n    let date = new Date();\n    let expiration = new Date(date.setDate(date.getDate() + 365));\n\n    if ( ! cookiesAccepted) {\n        document.cookie = \'cc_analytics=false; expires=\'+ days[expiration.getDay()] +\', \'+ expiration.getDate() +\' \'+ month[expiration.getMonth()] +\' \'+ expiration.getFullYear() +\' \'+ expiration.getHours() +\':\'+ expiration.getMinutes() +\':\'+ expiration.getSeconds() +\' UTC; path=/\';\n        document.cookie = \'cc_advertising=false; expires=\'+ days[expiration.getDay()] +\', \'+ expiration.getDate() +\' \'+ month[expiration.getMonth()] +\' \'+ expiration.getFullYear() +\' \'+ expiration.getHours() +\':\'+ expiration.getMinutes() +\':\'+ expiration.getSeconds() +\' UTC; path=/\';\n    }\n</script>\n    \n    \n        <title>\n            Аллергия и аллергический ринит\n     - apteka</title>\n\n        \n            <meta charset="utf-8">\n            <meta http-equiv="X-UA-Compatible" content="IE=edge">\n            <meta name="distribution" content="global"/>\n            <meta name="description" content="">\n            <meta name="keywords" content="">\n            <meta name="generator" content="Mauve Webshopsystem 3">\n            <meta name="revisit-after" content="3 Days">\n            <meta name="yandex-verification" content="9e571d2e04b1a424" />\n            \n            \n                \n                <meta name="viewport" content="width=device-width, initial-scale=1.0">\n            \n\n                                                                            \n\n        \n            \n                                                    <link rel="canonical" href="https://apteka.de/online-shop/allergie-heuschnupfen"/>\n                            \n\n            \n                                                                                                    <link rel="next" href="/online-shop/allergie-heuschnupfen?order_by=Relevance&order_direction=DESC&row=24"/>\n                                                \n        \n    \n\n    \n                                                    \n\n    \n        <link rel="stylesheet" type="text/css" href="/assets/master/tmp/main.min.96d9bd93.css" />\n\n        \n        \n            \n\n    \n            \n\n    \n        \n        <script src="/assets/master/js/src/available.js" type="text/javascript"></script>\n    \n\n    \n            \n    \n\n    \n            \n\n    \n        \n        \n    \n\n\n<script>\r\n    window.meshop = {"customer":{"signedIn":false},"form":{"titles":{"1":{"titleId":"1","name":"\\u0413\\u043e\\u0441\\u043f\\u043e\\u0434\\u0438\\u043d"},"2":{"titleId":"2","name":"\\u0413\\u043e\\u0441\\u043f\\u043e\\u0436\\u0430"},"3":{"titleId":"3","name":"\\u0421\\u0435\\u043c\\u044c\\u044f"},"4":{"titleId":"4","name":"\\u0424\\u0438\\u0440\\u043c\\u0430"}}}};\r\n</script><style type="text/css">#content {\n    max-width: 100%;\n}\n\nhtml[debug-cms=true] [debug="cms"] {\n    border: 2px solid #71b263 !important;\n    min-height: 20px;\n}\n\nhtml[debug-cms=true] [debug="cms"]::after {\n    content: "";\n    display: table;\n    clear: both;\n}\n\nhtml[debug-cms=true] [debug="cms"]:hover {\n    box-shadow: 0px 2px 20px rgba(0,0,0,.7);\n    position: relative;\n    z-index: 9998;\n}\n\nhtml[debug-cms=true] [debug="cms"]:hover {\n    border: 2px solid #54b200 !important;\n}\n\nhtml[debug-cms=true] [debug="cms"]:hover::before {\n    content: attr(data-params);\n    display: inline-block;\n    position: absolute;\n    left: 0;\n    top: 0;\n    z-index: 9999;\n    background-color: #54b200 !important;\n    color: #fff !important;\n    padding: 5px;\n    word-break: break-all;\n}\n\nhtml[debug-c ...

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ru">
# <head>
# <script>
#     let cookiesAccepted = document.cookie.indexOf("cookie-policy-accepted") != -1;
#     let month = new Array("Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct", "Nov", "Dec");
#     let days = new Array("Sun","Mon","Tue","Wed","Thu","Fri","Sat");
#     let date = new Date();
#     let expiration = new Date(date.setDate(date.getDate() + 365));
#
#     if ( ! cookiesAccepted) {
#         document.cookie = 'cc_analytics=false; expires='+ days[expiration.getDay()] +', '+ expiration.getDate() +' '+ month[expiration.getMonth()] +' '+ expiration.getFullYear() +' '+ expiration.getHours() +':'+ expiration.getMinutes() +':'+ expiration.getSeconds() +' UTC; path=/';
#         document.cookie = 'cc_advertising=false; expires='+ days[expiration.getDay()] +', '+ expiration.getDate() +' '+ month[expiration.getMonth()] +' '+ expiration.getFullYear() +' '+ expiration.getHours() +':'+ expiration.getMinutes() +':'+ expiration.getSeconds() +' UTC; path=/';
#     }
# </script>
# <title>
#             Аллергия и аллергический ринит
#      - apteka</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="global" name="distribution">
# <meta content="" name="description"/>
# <meta content="" name="keywords"/>
# <meta content="Mauve Webshopsystem 3" name="generator"/>
# <meta content="3 Days" name="revisit-after"/>
# <meta content="9e571d2e04b1a424" name="yandex-verification">
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="https://apteka.de/online-shop/allergie-heuschnupfen" rel="canonical"/>
# <link href="/online-shop/allergie-heuschnupfen?order_by=Relevance&amp;order_direction=DESC&amp;row=24" rel="next"/>
# <link href="/assets/master/tmp/main.min.96d9bd93.css" rel="stylesheet" type="text/css"/>
# <script src="/assets/master/js/src/available.js" type="text/javascript"></script>
# <script>
#     window.meshop = {"customer":{"signedIn":false},"form":{"titles":{"1":{"titleId":"1","name":"\u0413\u043e\u0441\u043f\u043e\u0434\u0438\u043d"},"2":{"titleId":"2","name":"\u0413\u043e\u0441\u043f\u043e\u0436\u0430"},"3":{"titleId":"3","name":"\u0421\u0435\u043c\u044c\u044f"},"4":{"titleId":"4","name":"\u0424\u0438\u0440\u043c\u0430"}}}};
# </script><style type="text/css">#content {
#     max-width: 100%;
# }
#
# html[debug-cms=true] [debug="cms"] {
#     border: 2px solid #71b263 !important;
#     min-height: 20px;
# }
#
# html[debug-cms=true] [debug="cms"]::after {
#     content: "";
#     display: table;
#     clear: both;
# }
#
# html[debug-cms=true] [debug="cms"]:hover {
#     box-shadow: 0px 2px 20px rgba(0,0,0,.7);
#     position: relative;
#     z-index: 9998;
# }
#
# html[debug-cms=true] [debug="cms"]:hover {
#     border: 2px solid #54b200 !important;
# }
#
# html[debug-cms=true] [debug="cms"]:hover::before {
#     content: attr(data-params);
#     display: inline-block;
#     position: absolute;
#     left: 0;
#     top: 0;
#     z-index: 9999;
#     background-color: #54b200 !important;
#     color: #fff !important;
#     padding: 5px;
#     word-break: break-all;
# }
#
# html[debug-cms=true] [debug="cms"] [debug="cms"]:hover::before {
#     content: attr(data-params);
#     display: inline-block;
#     position: absolute;
#     right: 0;
#     bottom: 0;
#     left:auto;
#     top:auto;
#     z-index: 9999;
#     background-color: #EC7007 !important;
#     color: #fff !important;
#     padding: 5px;
#     word-break: break-all;
# }
# html[debug-cms=true] [debug="cms"] [debug="cms"],
# html[debug-cms=true] [debug="cms"] [debug="cms"]:hover{
#     border: 2px solid #EC7007 !important;
# }
#
# [debug="shoptext"] {
#     text-decoration: none !important;
#     border: 0 !important;
# }
#
# html[debug-shoptext=true] [debug="shoptext"] {
#     outline: 2px solid #ab65b2 !important;
#     position: relative;
# }
#
# html[debug-shoptext=true] [debug="shoptext"]:hover {
#     outline: 2px solid #833db2 !important;
#     z-index: 9999;
# }
#
# html[debug-shoptext=true] [debug="shoptext"]:hover::after {
#     background-color: #833db2 !important;
#     content: attr(title);
#     color: #fff !important;
#     position: absolute;
#     left: 0;
#     top: 0;
#     z-index: 9999;
#     padding-left: 2px;
#     padding-right: 2px;
#     font-size: 12px;
#     line-height: 1.2;
# }
# </style><script>
#   window.dataLayer = window.dataLayer || []
#
#   function eventPush (event) {
#     if (typeof window.gtag !== 'undefined') {
#       gtag('event', event.event, event)
#     } else {
#       window.dataLayer.push(event)
#     }
#   }
#
#     window.dataLayer.push({"cart_items":[]})
#
#       eventPush({"event":"view_item_list","item_list_name":"\u0410\u043b\u043b\u0435\u0440\u0433\u0438\u044f \u0438 \u0430\u043b\u043b\u0435\u0440\u0433\u0438\u0447\u0435\u0441\u043a\u0438\u0439 \u0440\u0438\u043d\u0438\u0442","items":[{"item_id":"18113489","item_name":"Allegra Allergietabletten 20 mg","item_brand":"A. Nattermann & Cie GmbH","item_category":"\u0410\u043b\u043b\u0435\u0440\u0433\u0438\u044f \u0438 \u0430\u043b\u043b\u0435\u0440\u0433\u0438\u0447\u0435\u0441\u043a\u0438\u0439 \u0440\u0438\u043d\u0438\u0442","item_category_id":"1","price":6.55,"price_gross":7.79,"quantity":1},{"item_id":"17510656","item_name":"Allergodil akut forte 1,5 mg\/ml Nasenspray L\u00f6sung","item_brand":"Viatris Healthcare GmbH","item_category":"\u0410\u043b\u043b\u0435\u0440\u0433\u0438\u044f \u0438 \u0430\u043b\u043b\u0435\u0440\u0433\u0438\u0447\u0435\u0441\u043a\u0438\u0439 \u0440\u0438\u043d\u0438\u0442","item_category_id":"1","price":8.14,"price_gross":9.69,"quantity":1},{"item_id":"17538554","item_name":"Vividrin Azelastin EDO, bei Heuschnupfen und Allergien","item_brand":"Dr. Gerhard Mann Chem.-pharm.Fabrik GmbH","item_category":"\u0410\u043b\u043b\u0435\u0440\u0433\u0438\u044f \u0438 \u0430\u043b\u043b\u0435\u0440\u0433\u0438\u0447\u0435\u0441\u043a\u0438\u0439 \u0440\u0438\u043d\u0438\u0442","item_category_id":"1","price":5.87,"price_gross":6.99,"quantity":1},{"item_id":"17145955","item_name":"Desloratadin-Adgc 5 mg Filmtabletten","item_brand":"Zentiva Pharma GmbH","item_category":"\u0410\u043b\u043b\u0435\u0440\u0433\u0438\u044f \u0438 \u0430\u043b\u043b\u0435\u0440\u0433\u0438\u0447\u0435\u0441\u043a\u0438\u0439 \u0440\u0438\u043d\u0438\u0442","item_category_id":"1","price":13.08,"price_gross":15.56,"quantity":1},{"item_id":"17145949","item_name":"Desloratadin-Adgc 5 mg Filmtabletten","item_brand":"Zentiva Pharma GmbH","item_category":"\u0410\u043b\u043b\u0435\u0440\u0433\u0438\u044f \u0438 \u0430\u043b\u043b\u0435\u0440\u0433\u0438\u0447\u0435\u0441\u043a\u0438\u0439 \u0440\u0438\u043d\u0438\u0442","item_category_id":"1","price":6.99,"price_gross":8.32,"quantity":1},{"item_id":"17145932","item_name":"Desloratadin-Adgc 5 mg Filmtabletten","item_brand":"Zentiva Pharma GmbH","item_category":"\u0410\u043b\u043b\u0435\u0440\u0433\u0438\u044f \u0438 \u0430\u043b\u043b\u0435\u0440\u0433\u0438\u0447\u0435\u0441\u043a\u0438\u0439 \u0440\u0438\u043d\u0438\u0442","item_category_id":"1","price":3.32,"price_gross":3.95,"quantity":1},{"item_id":"16893833","item_name":"Abtei Meersalz Nasen Spray","item_brand":"Perrigo Deutschland GmbH","item_category":"\u0410\u043b\u043b\u0435\u0440\u0433\u0438\u044f \u0438 \u0430\u043b\u043b\u0435\u0440\u0433\u0438\u0447\u0435\u0441\u043a\u0438\u0439 \u0440\u0438\u043d\u0438\u0442","item_category_id":"1","price":3.61,"price_gross":4.3,"quantity":1},{"item_id":"16938180","item_name":"Desloratadin Heumann 5 mg Filmtabletten","item_brand":"HEUMANN PHARMA GmbH & Co. Generica KG","item_category":"\u0410\u043b\u043b\u0435\u0440\u0433\u0438\u044f \u0438 \u0430\u043b\u043b\u0435\u0440\u0433\u0438\u0447\u0435\u0441\u043a\u0438\u0439 \u0440\u0438\u043d\u0438\u0442","item_category_id":"1","price":33.15,"price_gross":39.45,"quantity":1},{"item_id":"16938174","item_name":"Desloratadin Heumann 5 mg Filmtabletten","item_brand":"HEUMANN PHARMA GmbH & Co. Generica KG","item_category":"\u0410\u043b\u043b\u0435\u0440\u0433\u0438\u044f \u0438 \u0430\u043b\u043b\u0435\u0440\u0433\u0438\u0447\u0435\u0441\u043a\u0438\u0439 \u0440\u0438\u043d\u0438\u0442","item_category_id":"1","price":18.54,"price_gross":22.06,"quantity":1},{"item_id":"16938145","item_name":"Desloratadin Heumann 5 mg Filmtabletten","item_brand":"HEUMANN PHARMA GmbH & Co. Generica KG","item_category":"\u0410\u043b\u043b\u0435\u0440\u0433\u0438\u044f \u0438 \u0430\u043b\u043b\u0435\u0440\u0433\u0438\u0447\u0435\u0441\u043a\u0438\u0439 \u0440\u0438\u043d\u0438\u0442","item_category_id":"1","price":8.38,"price_gross":9.97,"quantity":1},{"item_id":"16908368","item_n ...
#   </script>
# <script>
#     (function (w, d, s, l, i) {
#         w[l] = w[l] || [];
#         w[l].push({'gtm.start': new Date().getTime(), event: 'gtm.js'});
#         var f = d.getElementsByTagName(s)[0], j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
#         j.async = true;
#         j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#         f.parentNode.insertBefore(j, f);
#     })(window, document, 'script', 'dataLayer', 'GTM-K2FC265');
# </script></meta></meta></head>
# <body class="">
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-K2FC265" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <div id="app">
# <header>
# <div class="promotion-banner relative bg-primary text-white text-center px-3 py-2 hide">
# <div class="inline-block lg:ml-22">
# <span class="inline-block mb-2">
# <p><b>В связи с актуальной ситуацией отправка пакетов на Украину, в Россию и в Белоруссию, а также оформление заказов из этих стран, к сожалению невозможны.</b></p>
# </span>
# <a class="button-light ml-2" href="/versandkosten">Mehr</a>
# </div>
# <a class="absolute text-white flex items-center pin-r pin-y mr-3 ml-4" href="#">
# <span class="promotion-close">x</span>
# </a>
# </div>
# <aside class="header_topbar">
# <div class="container container--wide">
# <div class="flex pt-3 pb-2 items-center justify-between border-b border-grey">
# <div class="hidden-print">
# </div>
# <div class="text-center md:text-right">
# </div>
# <div></div>
# </div>
# </div>
# </aside>
# <div class="sticky pin-t z-10 md:relative container container--wide px-0">
# <div class="md:bg-transparent mx-auto flex flex-wrap md:flex-no-wrap items-center p-3 md:py-3 lg:pr-6 w-full justify-between flex-row">
# <a class="block w-64 sm:w-auto sm:max-w-full" href="https://apteka.de/" title="Стартовая страница">
# <img alt="Logo" src="/documents/logo/Logo Apteka 282x66.png"/>
# </a>
# <div class="user-nav md:order-last flex my-3 md:my-0">
# <a @click.prevent="emitEvent('offcanvas_open_account')" class="-ml-2 sm:-ml-0 text-xs text-center w-20 sm:w-auto text-grey-darker px-1 sm:px-2 lg:px-4 mx-1 sm:mx-0 icon-nav hover:text-primary" href="https://apteka.de/account/login" title="Зарегистрируйтесь здесь.">
# <div class="sm:w-16 m-auto">
# <img class="icon-nav__hover w-16" src="/assets/master/img/design/icons/icon-login-hover.svg"/><img class="icon-nav__regular w-16" src="/assets/master/img/design/icons/icon-login.svg"/>
# </div>
# <div class="hidden sm:block">Войти</div>
# </a>
# <a class="-ml-2 sm:-ml-0 text-xs text-center w-20 sm:w-auto text-grey-darker px-1 sm:px-2 lg:px-4 mx-1 sm:mx-0 icon-nav hover:text-primary relative" href="https://apteka.de/notepad">
# <div class="sm:w-16 m-auto">
# <img class="icon-nav__hover w-16" src="/assets/master/img/design/icons/icon-merkzettel-hover.svg?v=1"/><img class="icon-nav__regular w-16" src="/assets/master/img/design/icons/icon-merkzettel.svg"/>
# </div>
# <div class="hidden sm:block">Список отложенных товаров</div>
# </a>
# <a class="-ml-2 sm:-ml-0 text-xs text-center w-20 sm:w-auto text-grey-darker px-1 sm:px-2 lg:px-4 mx-1 sm:mx-0 icon-nav hover:text-primary lg:pr-0 relative" href="https://apteka.de/checkout/cart">
# <mini-cart class="text-sm"></mini-cart>
# <div class="sm:w-16 m-auto">
# <img class="icon-nav__hover w-16" src="/assets/master/img/design/icons/icon-cart-hover.svg"/><img class="icon-nav__regular w-16" src="/assets/master/img/design/icons/icon-cart.svg"/>
# </div>
# <div class="hidden sm:block">Корзина</div>
# </a>
# <a class="-ml-2 sm:-ml-0 text-xs text-center w-20 sm:w-auto text-grey-darker px-1 sm:px-2 lg:px-4 mx-1 sm:mx-0 icon-nav hover:text-primary lg:hidden flex flex-col justify-between -mr-1 sm:-mr-0 pr-0" href="#mobileNavigation" id="mobileNavigationButton" title="Все категории">
# <i class="fa fa-bars text-5xl mt-1" id="mobileNavigationIcon"></i>
# <div class="hidden sm:block">МЕНЮ</div>
# </a>
# </div>
# <speedfinder-search :is-primary="true" :is-products-only="false" :min-search-text-length="speedfinder.minSearchTextLength" :overwrite-search-term="speedfinder.searchTerm" @speedfinder_search_term_changed="onSpeedfinderSearchTermChange" class="w-full h-16 xl:ml-16 md:h-24 md:max-w-sm lg:max-w-md xl:max-w-lg">
# <form action="https://apteka.de/suche.html" class="w-full h-16 xl:ml-16 md:h-24" method="GET">
# <div class="relative bg-white z-10 flex shadow-md h-full">
# <input autocomplete="off" class="w-full pl-3" maxlength="128" name="term" placeholder="Товар, фармацевтический номер, действующее вещество..." type="text"/>
# <button class="bg-grey-light-dark hover:bg-grey-light-darker text-white text-base md:text-4xl m-0 px-4" tabindex="-1" type="submit" value="1">
# <i class="fa fa-search"></i>
# </button>
# </div>
# </form>
# </speedfinder-search>
# </div>
# </div>
# <div class="bg-grey">
# <div class="container container--mid relative page-wrap-top hidden sm:block">
# <img class="absolute pin-r -mt-2 hidden lg:block" src="/assets/master/img/design/apotheken-a-rund.png" style="z-index: 1;"/>
# <nav class="navmenu c-navmenu py-3 hidden-xs hidden-sm hidden-print">
# <ul class="o-nav o-nav__level o-nav__level--1 o-nav--inline"><li class="o-nav__item o-nav__item--has-children"><a class="active" href="/online-shop" title="Все категории">Все категории</a>
# <ul class="o-nav o-nav__level o-nav__level--2"><li class="o-nav__item"><a class="active" href="/online-shop/allergie-heuschnupfen" title="Аллергия и аллергический ринит">Аллергия и аллергический ринит</a></li><li class="o-nav__item"><a href="/online-shop/alles-fuer-die-frau" title="Все для женщин">Все для женщин</a></li><li class="o-nav__item"><a href="/online-shop/augen-nase-ohren" title="Глаза, нос, уши">Глаза, нос, уши</a></li><li class="o-nav__item"><a href="/online-shop/augenpflege" title="Уход за глазами">Уход за глазами</a></li><li class="o-nav__item"><a href="/online-shop/buecher-cd-dvd" title="Книги, CD и DVD">Книги, CD и DVD</a></li><li class="o-nav__item"><a href="/online-shop/diabetes" title="Диабет">Диабет</a></li><li class="o-nav__item"
a></li><li class="o-nav__item"><a href="/online-shop/kosmetik/koerper" title="Для тела">Для тела</a></li><li class="o-nav__item"><a href="/online-shop/kosmetik/make-up" title="Декоративная косметика">Декоративная косметика</a></li><li class="o-nav__item"><a href="/online-shop/kosmetik/maennerpflege" title="Средства по уходу для мужчин">Средства по уходу для мужчин</a></li><li class="o-nav__item"><a href="/online-shop/kosmetik/sonnenschutz-pflege" title="Солнцезащитные средства">Солнцезащитные средства</a></li></ul>
# </li><li class="o-nav__item o-nav__item--has-children"><a href="/online-shop/alles-fuer-die-frau" title="Все для женщин">Все для женщин</a>
# <ul class="o-nav o-nav__level o-nav__level--2"><li class="o-nav__item"><a href="/online-shop/alles-fuer-die-frau/blasenbeschwerden" title="Нарушения работы мочевого пузыря">Нарушения работы мочевого пузыря</a></li><li class="o-nav__item"><a href="/online-shop/alles-fuer-die-frau/eisenmangel" title="Дефицит железа">Дефицит железа</a></li><li class="o-nav__item"><a href="/online-shop/alles-fuer-die-frau/intimhygiene" title="Интимная гигиена">Интимная гигиена</a></li><li class="o-nav__item"><a href="/online-shop/alles-fuer-die-frau/pilzinfektionen" title="Грибковая инфекция">Грибковая инфекция</a></li><li class="o-nav__item"><a href="/online-shop/alles-fuer-die-frau/regelbeschwerden" title="Менструальные боли">Менструальные боли</a></li><li class="o-nav__item"><a href="/online-shop/alles-fuer-die-frau/scheidentrockenheit" title="Сухость влагалища">Сухость влагалища</a></li><li class="o-nav__item"><a href="/online-shop/alles-fuer-die-frau/sexuelle-unlust" title="Отсутствие сексуального желания">Отсутствие сексуального желания</a></li><li class="o-nav__item"><a href="/online-shop/alles-fuer-die-frau/wechseljahre" title="Климакс">Климакс</a></li></ul>
# </li><li class="o-nav__item o-nav__item--has-children"><a href="/online-shop/vegan-vegetarisch" title="Для веганов и вегетарианцев">Для веганов и вегетарианцев</a>
# <ul class="o-nav o-nav__level o-nav__level--2"><li class="o-nav__item"><a href="/online-shop/vegan-vegetarisch/haut-haare-naegel" title="Кожа, волосы, ногти">Кожа, волосы, ногти</a></li><li class="o-nav__item"><a href="/online-shop/vegan-vegetarisch/kosmetik" title="Косметика">Косметика</a></li><li class="o-nav__item"><a href="/online-shop/vegan-vegetarisch/magen-darm-verdauung" title="Желудок, кишечник и пищеварение">Желудок, кишечник и пищеварение</a></li><li class="o-nav__item"><a href="/online-shop/vegan-vegetarisch/muskeln-knochen-gelenke" title="Мышцы, кости и суставы">Мышцы, кости и суставы</a></li><li class="o-nav__item"><a href="/online-shop/vegan-vegetarisch/nahrungsergaenzung" title="Пищевые добавки">Пищевые добавки</a></li><li class="o-nav__item"><a href="/online-shop/vegan-vegetarisch/sexualitaet" title="Половая жизнь">Половая жизнь</a></li><li class="o-nav__item"><a href="/online-shop/vegan-vegetarisch/sonstiges" title="Прочее">Прочее</a></li><li class="o-nav__item"><a href="/online-shop/vegan-vegetarisch/tees-kraeuter" title="Чаи и травы">Чаи и травы</a></li><li class="o-nav__item"><a href="/online-shop/vegan-vegetarisch/zahnpflege" title="Уход за зубами">Уход за зубами</a></li></ul>
# </li><li class="o-nav__item o-nav__item--has-children"><a href="/online-shop/wellness" title="Оздоровление">Оздоровление</a>
# <ul class="o-nav o-nav__level o-nav__level--2"><li class="o-nav__item"><a href="/online-shop/wellness/aromatherapie" title="Ароматерапия">Ароматерапия</a></li><li class="o-nav__item"><a href="/online-shop/wellness/bad-sauna" title="Ванна и сауна">Ванна и сауна</a></li><li class="o-nav__item"><a href="/online-shop/wellness/bonbons" title="Леденцы">Леденцы</a></li><li class="o-nav__item"><a href="/online-shop/wellness/massage" title="Массаж">Массаж</a></li><li class="o-nav__item"><a href="/online-shop/wellness/struempfe-einlagen" title="Чулки и стельки">Чулки и стельки</a></li><li class="o-nav__item"><a href="/online-shop/wellness/waermflaschen-kissen" title="Грелки и греющие подушки ">Грелки и греющие подушки </a></li></ul>
# </li></ul>
# </nav>
# </div>
# </div>
# </header>
# <div>
# <div class="container my-2">
# </div>
# </div>
# <main class="section-main container page-wrap-bottom">
# <ol class="breadcrumb bg-transparent">
# <li><a class="text-grey-darker hover:text-grey-dark text-sm" href="https://apteka.de/" title="Стартовая страница">Стартовая страница</a></li>
# <li class="active text-grey-darker text-sm">Аллергия и аллергический ринит</li>
# </ol>
# <div class="row">
# <div class="col-md-3 visible-lg visible-md hidden-print">
# <h2 class="h2">категории</h2>
# <ul class="navigation-list list-reset font-sari leading-loose level-1">
# <li class="Selected">
# <a class="active" href="/online-shop/allergie-heuschnupfen" title="Аллергия и аллергический ринит">Аллергия и аллергический ринит</a>
# <ul class="list-reset pl-2 level-2">
# <li>
# <a href="/online-shop/allergie-heuschnupfen/allergie-heuschnupfen-unterstuetzend" title="Поддерживающие препараты при аллергии и аллергическом рините">Поддерживающие препараты при аллергии и аллергическом рините</a>
# </li>
# <li>
# <a href="/online-shop/allergie-heuschnupfen/soforthilfe" title="Неотложная помощь">Неотложная помощь</a>
# </li>
# <li>
# <a href="/online-shop/allergie-heuschnupfen/vorbeugend" title="Профилактика">Профилактика</a>
# </li>
# <li>
# <a href="/online-shop/allergie-heuschnupfen/zubehoer" title="Сопутствующие товары">Сопутствующие товары</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="/online-shop/schmerzmittel" title="Болеутоляющие средства">Болеутоляющие средства</a>
# </li>
# <li>
# <a href="/online-shop/raucherentwoehnung" title="Борьба с курением">Борьба с курением</a>
# </li>
# <li>
# <a href="/online-shop/vitamine-mineralien-enzyme" title="Витамины, минералы и ферменты">Витамины, минералы и ферменты</a>
# </li>
# <li>
# <a href="/online-shop/alles-fuer-die-frau" title="Все для женщин">Все для женщин</
href="/online-shop/tees-kraeuter" title="Чаи и травы">Чаи и травы</a>
# </li>
# </ul>
# </div>
# <div class="col-md-9">
# <h1 class="h2">Обзор Аллергия и аллергический ринит</h1>
# <script type="text/javascript">
#     available.objAvailable('shop', function(o) {
#         o.description('Подробнее', 'свернуть', 100);
#     });
# </script>
# <div class="text-center">
# <style media="screen" type="text/css">
# </style>
# <div id="kairion-super"> </div>
# </div>
# <div class="hidden-md hidden-lg mb-3">
# <a class="button-primary" href="#mobileNavigation">Другие группы товаров</a>
# </div>
# <div class="row mt1 after-search">
# <form action="/online-shop/allergie-heuschnupfen" id="asnformbox" method="get" name="asnformbox">
# <input id="asntextbox" name="q" type="hidden" value="">
# <div class="col-xs-12">
# <div class="hidden-xs">
# <strong>фильтр товаров</strong>
# <p>Сузить поиск</p>
# <hr class="hr my1"/>
# </div>
# </div>
# <input id="asnfield_submit" name="searchfield_submit" type="hidden" value="1"/>
# <input name="order_by" type="hidden" value="Relevance"/>
# <input name="order_direction" type="hidden" value="DESC"/>
# <input name="range" type="hidden" value="24"/>
# <div class="clearfix"></div>
# <div class="col-xs-6 visible-xs visible-sm">
# <a class="button-primary hidden-md hidden-lg" data-toggle="collapse" href="#afterSearch">Suchfilter anzeigen</a>
# </div>
# <div class="collapse-xs collapse-sm" id="afterSearch">
# <div class="col-xs-12 col-sm-6 col-md-4 mb1">
# <label class="sr-only" for="asn_filter_672c8cde59d2b">Производитель</label>
# <div class="styled-multi-select col-12">
# <select data-label="Производитель" id="asn_filter_672c8cde59d2b" multiple="" name="filter[Hersteller][]">
# <option data-count="3" value="1 A Pharma GmbH">1 A Pharma GmbH</option>
# <option data-count="1" value="A. Nattermann &amp; Cie GmbH">A. Nattermann &amp; Cie GmbH</option>
# <option data-count="3" value="AbZ Pharma GmbH">AbZ Pharma GmbH</option>
# <option data-count="6" value="ALIUD Pharma GmbH">ALIUD Pharma GmbH</option>
# <option data-count="6" value="Aristo Pharma GmbH">Aristo Pharma GmbH</option>
# <option data-count="8" value="axicorp Pharma GmbH">axicorp Pharma GmbH</option>
# <option data-count="8" value="betapharm Arzneimittel GmbH">betapharm Arzneimittel GmbH</option>
# <option data-count="3" value="Blanco Pharma GmbH">Blanco Pharma GmbH</option>
# <option data-count="3" value="CEGLA Medizintechnik GmbH">CEGLA Medizintechnik GmbH</option>
# <option data-count="6" value="DERMAPHARM AG">DERMAPHARM AG</option>
# <option data-count="1" value="Dexcel Pharma GmbH">Dexcel Pharma GmbH</option>
# <option data-count="3" value="DHU-Arzneimittel GmbH &amp; Co. KG">DHU-Arzneimittel GmbH &amp; Co. KG</option>
# <option data-count="2" value="Dr. Gerhard Mann Chem.-pharm.Fabrik GmbH">Dr. Gerhard Mann Chem.-pharm.Fabrik GmbH</option>
# <option data-count="1" value="Dreluso-Pharmazeutika Dr.Elten &amp; Sohn GmbH">Dreluso-Pharmazeutika Dr.Elten &amp; Sohn GmbH</option>
# <option data-count="2" value="GALENpharma GmbH">GALENpharma GmbH</option>
# <option data-count="4" value="Glenmark Arzneimittel GmbH">Glenmark Arzneimittel GmbH</option>
# <option data-count="1" value="Haleon Germany GmbH">Haleon Germany GmbH</option>
# <option data-count="4" value="HEUMANN PHARMA GmbH &amp; Co. Generica KG">HEUMANN PHARMA GmbH &amp; Co. Generica KG</option>
# <option data-count="2" value="Hevert-Arzneimittel GmbH &amp; Co. KG">Hevert-Arzneimittel GmbH &amp; Co. KG</option>
# <option data-count="16" value="Hexal AG">Hexal AG</option>
# <option data-count="3" value="IMP GmbH International Medical Products">IMP GmbH International Medical Products</option>
# <option data-count="4" value="Johnson &amp; Johnson GmbH (OTC)">Johnson &amp; Johnson GmbH (OTC)</option>
# <option data-count="3" value="Micro Labs GmbH">Micro Labs GmbH</option>
# <option data-count="3" value="OmniVision GmbH">OmniVision GmbH</option>
# <option data-count="2" value="Perrigo Deutschland GmbH">Perrigo Deutschland GmbH</option>
# <option data-count="1" value="plantoCAPS pharm GmbH">plantoCAPS pharm GmbH</option>
# <option data-count="12" value="ratiopharm GmbH">ratiopharm GmbH</option>
# <option data-count="1" value="SANUM-KEHLBECK GmbH &amp; Co. KG">SANUM-KEHLBECK GmbH &amp; Co. KG</option>
# <option data-count="1" value="Sidroga Gesellschaft für Gesundheitsprodukte mbH">Sidroga Gesellschaft für Gesundheitsprodukte mbH</option>
# <option data-count="4" value="Spenglersan GmbH">Spenglersan GmbH</option>
# <option data-count="3" value="STADA Consumer Health Deutschland GmbH">STADA Consumer Health Deutschland GmbH</option>
# <option data-count="6" value="TAD Pharma GmbH">TAD Pharma GmbH</option>
# <option data-count="6" value="Viatris Healthcare GmbH">Viatris Healthcare GmbH</option>
# <option data-count="2" value="WEBER &amp; WEBER GmbH">WEBER &amp; WEBER GmbH</option>
# <option data-count="10" value="Zentiva Pharma GmbH">Zentiva Pharma GmbH</option>
# </select>
# </div>
# <div class="clearfix"></div>
# </div>
# <div class="col-xs-12 col-sm-6 col-md-4 mb1">
# <label class="sr-only" for="asn_filter_672c8cde59d85">лекарственная форма</label>
# <div class="styled-multi-select col-12">
# <select data-label="лекарственная форма" id="asn_filter_672c8cde59d85" multiple="" name="filter[Darreichungsform][]">
# <option data-count="8" value="Augentropfen">Augentropfen</option>
# <option data-count="3" value="Einzeldosispipetten">Einzeldosispipetten</option>
# <option data-count="63" value="Filmtabletten">Filmtabletten</option>
# <option data-count="3" value="Kapseln">Kapseln</option>
# <option data-count="6" value="Kombipackung">Kombipackung</option>
# <option data-count="1" value="Lösung">Lösung</option>
# <option data-count="4" value="Lösung zum Einnehmen">Lösung zum Einnehmen</option>
# <option data-count="2" value="Mischung">Mischung</option>
# <option data-count="1" value="Nasendosierspray">Nasendosierspray</option>
# <option data-count="22" value="Nasenspray">Nasenspray</option>
# <option data-count="3" value="Pflaster">Pflaster</option>
# <option data-count="1" value="Saft">Saft</option>
# <option data-count="1" value="Spray">Spray</option>
# <option data-count="21" value="Tabletten">Tabletten</option>
# <option data-count="3" value="Tropfen">Tropfen</option>
# <option data-count="1" value="Tube">Tube</option>
# </select>
# </div>
# <div class="clearfix"></div>
# </div>
# <div class="col-xs-12 col-sm-6 col-md-4 mb1">
# <label class="sr-only" for="asn_filter_672c8cde59da9">Единица измерения упаковки</label>
# <div class="styled-multi-select col-12">
# <select data-label="Единица измерения упаковки" id="asn_filter_672c8cde59da9" name="filter[Verpackungseinheit][]" onchange="if(this.value[0]) this.form.submit();">
# <option disabled="" selected="" value="">Единица измерения упаковки</option>
# <option data-count="9" value="g">g</option>
# <option data-count="37" value="ml">ml</option>
# <option data-count="3" value="P">P</option>
# <option data-count="95" value="St">St</option>
# </select>
# </div>
# <div class="clearfix"></div>
# </div>
# <div class="col-xs-12 col-sm-6 col-md-4 mb1">
# <label class="sr-only" for="asn_filter_672c8cde59db5">Действующее вещество</label>
# <div class="styled-multi-select col-12">
# <select data-label="Действующее вещество" id="asn_filter_672c8cde59db5" multiple="" name="filter[Wirkstoff][]">
# <option data-count="11" value="Azelastin hydrochlorid">Azelastin hydrochlorid</option>
# <option data-count="1" value="Bilastin">Bilastin</option>
# <option data-count="28" value="Cetirizin dihydrochlorid">Cetirizin dihydrochlorid</option>
# <option data-count="4" value="Cromoglicinsäure, Dinatriumsalz">Cromoglicinsäure, Dinatriumsalz</option>
# <option data-count="21" value="Desloratadin">Desloratadin</option>
# <option data-count="1" value="Fluticason 17-propionat">Fluticason 17-propionat</option>
# <option data-count="3" value="Ketotifen fumarat">Ketotifen fumarat</option>
# <option data-count="7" value="Levocabastin hydrochlorid">Levocabastin hydrochlorid</option>
# <option data-count="20" value="Levocetirizin dihydrochlorid">Levocetirizin dihydrochlorid</option>
# <option data-count="11" value="Loratadin">Loratadin</option>
# <option data-count="9" value="Mometason furoat-1-Wasser">Mometason furoat-1-Wasser</option>
# <option data-count="2" value="Xylometazolin hydrochlorid">Xylometazolin hydrochlorid</option>
# </select>
# </div>
# <div class="clearfix"></div>
# </div>
# <div class="col-xs-12 col-sm-6 col-md-4 mb1">
# <label class="sr-only" for="asn_filter_672c8cde59dc6">цена</label>
# <div class="styled-multi-select col-12">
# <select data-label="цена" id="asn_filter_672c8cde59dc6" multiple="" name="filter[Preis][]">
# <option data-count="58" value="Preis ge 5m and Preis le 9.99m">5 € - 9,99 €</option>
# <option data-count="47" value="Preis ge 10m and Preis le 24.99m">10 € - 24,99 €</option>
# <option data-count="14" value="Preis ge 25m and Preis le 49.99m">25 € - 49,99 €</option>
# <option data-count="1" value="Preis ge 50m and Preis le 199.99m">50 € - 199,99 €</option>
# <option data-count="24" value="Preis lt 5m">&lt; 5 €</option>
# </select>
# </div>
# <div class="clearfix"></div>
# </div>
# <div class="clearfix mb-3"></div>
# <div class="col-xs-12">
# <div class="my1">
# <a class="btn btn-reset btn-rounded btn-xs px2" href="//online-shop/allergie-heuschnupfen">Сбросить все фильтры</a>
# </div>
# </div>
# </div>
# </input></form>
# <div class="col-xs-6 visible-xs visible-sm">
# <div class="toolbar">
# <form action="/online-shop/allergie-heuschnupfen" id="toolbox" method="get" name="toolbox">
# <input id="asntextbox" name="q" type="hidden" value=""/>
# <input id="asnfield_submit" name="searchfield_submit" type="hidden" value="1"/>
# <div class="form-group row">
# <div class="col-xs-12 col-sm-8 form-inline">
# <div class="form-group hidden-xs">
# <label class="control-label" for="order_by">Сортировка:</label>
# </div>
# <div class="form-group inline-block">
# <div class="styled-multi-select styled-multi-select-minimal styled-multi-select-small multi-select-sort">
# <label class="sr-only" for="sort">Сортировка:</label>
# <select id="order_by" name="sort">
# <option selected="selected" value="Relevance-DESC">Актуальность</option>
# <option value="Availability-ASC">Verfügbarkeit по возрастанию</option>
# <option value="Availability-DESC">Verfügbarkeit по убыванию</option>
# <option value="Name-ASC">Имя A-Z</option>
# <option value="Name-DESC">Имя Z-A</option>
# <option value="Price-ASC">Цена по возрастанию</option>
# <option value="Price-DESC">Цена по убыванию</option>
# <option value="Manufacturer-ASC">производитель A-Z</option>
# <option value="Manufacturer-DESC">производитель Z-A</option>
# </select>
# </div>
# </div>
# </div>
# <div class="col-xs-4 col-sm-4 hidden-xs">
# <div class="product-group__viewmode mb-2 text-right">
# <button @click.prevent="switchProductGroupViewMode('matrix')" class="product-group__viewmode__button product-group__viewmode__button--matrix btn btn-default active" title="Auf Matrix-Ansicht umstellen" type="button"><i class="fa fa-th"></i></button>
# <button @click.prevent="switchProductGroupViewMode('list')" class="product-group__viewmode__button product-group__viewmode__button--list btn btn-default" title="Auf Listen-Ansicht umstellen" type="button"><i class="fa fa-bars"></i></button>
# </div>
# </div>
# </div>
# </form>
# </div>
# </div>
# <div class="clearfix"></div>
# </div>
# <hr class="hr mb1"/>
# <div class="hidden-xs hidden-sm">
# <div class="toolbar">
# <form action="/online-shop/allergie-heuschnupfen" id="toolbox" method="get" name="toolbox">
# <input id="asntextbox" name="q" type="hidden" value=""/>
# <input id="asnfield_submit" name="searchfield_submit" type="hidden" value="1"/>
# <div class="form-group row">
# <div class="col-xs-12 col-sm-8 form-inline">
# <div class="form-group hidden-xs">
# <label class="control-label" for="order_by">Сортировка:</label>
# </div>
# <div class="form-group inline-block">
# <div class="styled-multi-select styled-multi-select-minimal styled-multi-select-small multi-select-sort">
# <label class="sr-only" for="sort">Сортировка:</label>
# <select id="order_by" name="sort">
# <option selected="selected" value="Relevance-DESC">Актуальность</option>
# <option value="Availability-ASC">Verfügbarkeit по возрастанию</option>
# <option value="Availability-DESC">Verfügbarkeit по убыванию</option>
# <option value="Name-ASC">Имя A-Z</option>
# <option value="Name-DESC">Имя Z-A</option>
# <option value="Price-ASC">Цена по возрастанию</option>
# <option value="Price-DESC">Цена по убыванию</option>
# <option value="Manufacturer-ASC">производитель A-Z</option>
# <option value="Manufacturer-DESC">производитель Z-A</option>
# </select>
# </div>
# </div>
# </div>
# <div class="col-xs-4 col-sm-4 hidden-xs">
# <div class="product-group__viewmode mb-2 text-right">
# <button @click.prevent="switchProductGroupViewMode('matrix')" class="product-group__viewmode__button product-group__viewmode__button--matrix btn btn-default active" title="Auf Matrix-Ansicht umstellen" type="button"><i class="fa fa-th"></i></button>
# <button @click.prevent="switchProductGroupViewMode('list')" class="product-group__viewmode__button product-group__viewmode__button--list btn btn-default" title="Auf Listen-Ansicht umstellen" type="button"><i class="fa fa-bars"></i></button>
# </div>
# </div>
# </div>
# </form>
# </div>
# </div>
# <div class="products">
# <div class="row flex flex-wrap product-grid product-grid--matrix">
# <div class="product-box-container flex col-sm-6 col-md-4 col-xs-12 mb-4">
# <div class="bg-white product-box flex">
# <div class="product-box__image text-center p-0 md:p-2">
# <a href="/online-kaufen/allegra-allergietabletten-20-mg-18113489" title="Allegra Allergietabletten 20 mg">
# <img alt="Allegra Allergietabletten 20 mg" src="/documents/products/Listenansicht/1011719058.jpg" style="margin: auto" title="Allegra Allergietabletten 20 mg">
# </img></a>
# <div class="bg-primary text-white flex flex-col justify-between text-center leading-none absolute pin-t z-1 rounded-full mt-3 pin-r w-24 h-24 text-base">
# <span class="my-auto">-36 %<sup>1</sup></span>
# </div>
# </div>
# <div class="product-box__meta">
# <div class="productrating">
# </div>
# <h4 class="product-box__title mt-0 mb-2"><a class="text-grey-darker h4 text-base mb-0" href="/online-kaufen/allegra-allergietabletten-20-mg-18113489" title="Allegra Allergietabletten 20 mg">Allegra Allergietabletten 20 mg</a></h4>
# <div class="list-meta">
# <div>
# <span class="font-sari">Форма выпуска: Tabletten</span>
# </div>
# <div>
# <span class="font-sari">Содержание:</span> 20 St
#                                     </div>
# <div>
# <span class="font-sari">Фармацевтический номер:</span> 18113489
#                                 </div>
# <div>
# <span class="font-sari">Производитель:</span> A. Nattermann &amp; Cie GmbH
#                                                                     </div>
# <p class="delivery-time"> <img alt="в наличии" class="delivery-time-image" src="/documents/delivery_times/delivery-three.png" title="в наличии"> <small> в наличии</small></img></p>
# </div>
# </div>
# <div class="product-box__bottom">
# <div class="product-box__bottom__wrap text-grey-dark base-price-boxed">
#
#                                                                 20 St
#                                     <div class="pull-right">
# </div>
# </div>
# <div class="product-box__bottom__wrap">
# <div>
# <div class="line-through">
#                                         12,20 €
#                                     </div>
# </div>
# <div class="product-box__price">
# <div class="mb-0 text-base text-secondary">
#
#                                         7,79 €
#
#                                     </div>
# </div>
# <div class="base-price-list text-grey-dark">
# </div>
# <p class="small product-shipping-info">
#                                                                     Вкл. НДС"
#                                                                 при необходимости включая <a data-target="#content-modal" data-title="Versandkosten" data-toggle="content-modal" href="/ajax/content/versandkosten.20005.html" rel="nofollow">стоимость доставки</a>
# </p>
# </div>
# <form @submit.prevent="emitEvent('cart_update', $event)" action="https://apteka.de/checkout/cart/add/product" class="text-right flex-1 justify-end product-submit-form" method="post">
# <input name="product[product_id]" type="hidden" value="946185"/>
# <input name="options[PrescriptionType]" type="hidden" value="0"/>
# <div class="quantity-picker flex">
# <button @click.prevent="stepDown('quantity672c8cde5e0cd')" class="quantity-picker__minus text-grey-dark" href="#" type="button">
# <i class="fa fa-minus"></i>
# </button>
# <input autocomplete="off" class="quantity-picker__field text-grey-dark" id="quantity672c8cde5e0cd" min="1" name="product[quantity]" step="1" type="number" value="1"/>
# <button @click.prevent="stepUp('quantity672c8cde5e0cd')" class="quantity-picker__plus text-grey-dark" href="#" type="button">
# <i class="fa fa-plus"></i>
# </button>
# </div>
# <button class="product-box__tocart text-white bg-secondary px-2 md:w-full" name="refresh_submit" title="В корзину" type="submit" value=""><i class="fa fa-shopping-cart"></i><span class="text-base"> добавлено в  корзину.</span></button>
# </form>
# </div>
# </div>
# </div>
# <div class="product-box-container flex col-sm-6 col-md-4 col-xs-12 mb-4">
# <div class="bg-white product-box flex">
# <div class="product-box__image text-center p-0 md:p-2">
# <a href="/online-kaufen/allergodil-akut-forte-1-5-mg-ml-nasenspray-loesung-17510656" title="Allergodil akut forte 1,5 mg/ml Nasenspray Lösung">
# <img alt="Allergodil akut forte 1,5 mg/ml Nasenspray Lösung" src="/documents/products/Listenansicht/1008674237.jpg" style="margin: auto" title="Allergodil akut forte 1,5 mg/ml Nasenspray Lösung">
# </img></a>
# <div class="bg-primary text-white flex flex-col justify-between text-center leading-none absolute pin-t z-1 rounded-full mt-3 pin-r w-24 h-24 text-base">
# <span class="my-auto">-35 %<sup>1</sup></span>
# </div>
# </div>
# <div class="product-box__meta">
# <div class="productrating">
# </div>
# <h4 class="product-box__title mt-0 mb-2"><a class="text-grey-darker h4 text-base mb-0" href="/online-kaufen/allergodil-akut-forte-1-5-mg-ml-nasenspray-loesung-17510656" title="Allergodil akut forte 1,5 mg/ml Nasenspray Lösung">Allergodil akut forte 1,5 mg/ml Nasenspray Lösung</a></h4>
# <div class="list-meta">
# <div>
# <span class="font-sari">Форма выпуска: Nasenspray</span>
# </div>
# <div>
# <span class="font-sari">Содержание:</span> 10 ml
#                                     </div>
# <div>
# <span class="font-sari">Фармацевтический номер:</span> 17510656
#                                 </div>
# <div>
# <span class="font-sari">Производитель:</span> Viatris Healthcare GmbH
#                                                                     </div>
# <p class="delivery-time"> <img alt="в наличии" class="delivery-time-image" src="/documents/delivery_times/delivery-three.png" title="в наличии"> <small> в наличии</small></img></p>
# </div>
# </div>
# <div class="product-box__bottom">
# <div class="product-box__bottom__wrap text-grey-dark base-price-boxed">
#
#                                                                 10 ml
#                                     <div class="pull-right">
# <span class="font-sari base-price-label">Базовый тариф:</span>
#                                                                                                                             969,00 € / 1 l
#                                                                             </div>
# </div>
# <div class="product-box__bottom__wrap">
# <div>
# <div class="line-through">
#                                         14,95 €
#                                     </div>
# </div>
# <div class="product-box__price">
# <div class="mb-0 text-base text-secondary">
#
#                                         9,69 €
#
#                                     </div>
# </div>
# <div class="base-price-list text-grey-dark">
# <div class="product-box__meta_p mb-0 base-price">
# ...
# <ul class=""><li><a href="/online-shop/kosmetik/gesicht/24-h-pflege" title="Уход 24 часа">Уход 24 часа</a></li><li><a href="/online-shop/kosmetik/gesicht/anti-age-pflege" title="Антивозрастной уход">Антивозрастной уход</a></li><li><a href="/online-shop/kosmetik/gesicht/augenpflege" title="Уход за глазами">Уход за глазами</a></li><li><a href="/online-shop/kosmetik/gesicht/lippenpflege" title="Средства для ухода за губами">Средства для ухода за губами</a></li><li><a href="/online-shop/kosmetik/gesicht/masken-co" title="Маски и прочее">Маски и прочее</a></li><li><a href="/online-shop/kosmetik/gesicht/nachtpflege" title="Ночной уход">Ночной уход</a></li><li><a href="/online-shop/kosmetik/gesicht/pigmentpflege" title="Средства по уходу при пигментации">Средства по уходу при пигментации</a></li><li><a href="/online-shop/kosmetik/gesicht/reinigung" title="Очищение">Очищение</a></li><li><a href="/online-shop/kosmetik/gesicht/tagespflege" title="Уход за престарелами">Уход за престарелами</a></li></ul>
# </ul></li><li><a href="/online-shop/kosmetik/hand-fuss" title="Для ухода за кожей рук и ног">Для ухода за кожей рук и ног</a><ul>
# <ul class=""><li><a href="/online-shop/kosmetik/hand-fuss/fussfrische" title=" Антиперспирант для ног"> Антиперспирант для ног</a></li><li><a href="/online-shop/kosmetik/hand-fuss/blasen" title="Мозоли">Мозоли</a></li><li><a href="/online-shop/kosmetik/hand-fuss/diabetischer-fuss" title="Уход за ногами при диабете">Уход за ногами при диабете</a></li><li><a href="/online-shop/kosmetik/hand-fuss/fusspflege" title="Уход за кожей ног">Уход за кожей ног</a></li><li><a href="/online-shop/kosmetik/hand-fuss/handpflege" title="Уход за кожей рук">
# </ul></li><li><a href="/online-shop/wellness/bad-sauna" title="Ванна и сауна">Ванна и сауна</a><ul>
# <ul class=""><li><a href="/online-shop/wellness/bad-sauna/badekristalle" title="Кристаллы для ванны">Кристаллы для ванны</a></li><li><a href="/online-shop/wellness/bad-sauna/badeperlen-kugeln" title="Жемчужины и бомобчки для ванны">Жемчужины и бомобчки для ванны</a></li><li><a href="/online-shop/wellness/bad-sauna/badezubehoer" title="Сопутствующие товары для ванны">Сопутствующие товары для ванны</a></li><li><a href="/online-shop/wellness/bad-sauna/gesundheitsbaeder" title="Оздоровляющие ванны">Оздоровляющие ванны</a></li><li><a href="/online-shop/wellness/bad-sauna/oelbaeder" title="Масла для ванны">Масла для ванны</a></li><li><a href="/online-shop/wellness/bad-sauna/saunaaufguesse" title="Настои для сауны">Настои для сауны</a></li><li><a href="/online-shop/wellness/bad-sauna/schaumbaeder" title="Пена для ванн">Пена для ванн</a></li></ul>
# </ul></li><li><a href="/online-shop/wellness/bonbons" title="Леденцы">Леденцы</a></li><li><a href="/online-shop/wellness/massage" title="Массаж">Массаж</a></li><li><a href="/online-shop/wellness/struempfe-einlagen" title="Чулки и стельки">Чулки и стельки</a></li><li><a href="/online-shop/wellness/waermflaschen-kissen" title="Грелки и греющие подушки ">Грелки и греющие подушки </a></li></ul>
# </ul></li></ul>
# </ul>
# </nav>
# <script type="text/javascript">
#             available.objAvailable('shop', function (o) {
#                 o.initMMenu('#mobileNavigation', true);
#             });
#         </script>
# <script type="text/javascript">window.shoptexts = {'search': {'placeholder': 'На латинице: название, PZN или дейст. вещество','noResult': 'Нет результатов','products': 'Рекомендованные товары','goToAll': 'Показать все результаты','manufacturer': 'Производитель','productGroups': 'Категории','suggestions': 'Предложения','redirects': 'Переадрессация','searching': '""Поиск результатов..."','minimumCharactersPre': 'Поиск  должен как минимум','minimumCharactersAfter': 'содержать знаков.'},'cartSummary' : {'empty' : 'Корзина пуста.','total' : 'Промежуточная сумма','priceInfo' : 'Цены Вкл. НДС" при необходимости включая стоимость доставки','addedToCart': 'добавлено в  корзину.','toCheckout': 'К оплате','shippingHeadline': 'Не хватает до бесплатной доставки','edit': 'К корзине','continueShopping': 'Продолжить покупки','crossSellingHeadline': 'Любимые продукты','crossSellingGoToProduct': 'К товару',},'offcanvas': {'continueShopping': 'Продолжить покупки'},'modal': {'close' : 'Закрыть'},'notepad': {'add_to_notepad': 'В Списке отложенных товаров','remove_from_notepad': 'Vom Merkzettel entfernen'},'revocation': {'cancel_all': 'Я хочу отказаться от всего заказа','cancel_some': 'Я хочу отказаться от следующих товаров в заказе','product_number': 'Товар №','amount': 'Количество','add_product': 'Добавить товар'}}</script>
# <script src="/assets/master/tmp/main.min.2a4ef640.js" type="text/javascript"></script>
# <script>
#         let promoBanner = document.querySelector(".promotion-banner");
#         let promoButtonClose = document.querySelector(".promotion-close");
#         if (promoBanner) {
#             let userClass = promoBanner.classList[0];
#             let cookieName = 'promoBannerClosed' + userClass;
#             let userCookie = getCookie(cookieName);
#             if(userCookie != 'closed'){
#                 promoBanner.classList.remove("hide");
#             }
#             promoButtonClose.addEventListener('click', function(e){
#                 e.preventDefault();
#                 setCookie(cookieName, 'closed', 90)
#                 promoBanner.classList.add("hide");
#             });
#         }
#
#         function getCookie(cname) {
#             var name = cname + "=";
#             var decodedCookie = decodeURIComponent(document.cookie);
#             var ca = decodedCookie.split(';');
#             for(var i = 0; i <ca.length; i++) {
#                 var c = ca[i];
#                 while (c.charAt(0) == ' ') {
#                     c = c.substring(1);
#                 }
#                 if (c.indexOf(name) == 0) {
#                     return c.substring(name.length, c.length);
#                 }
#             }
#             return "";
#         }
#
#         function setCookie(cname, cvalue, exdays) {
#             var d = new Date();
#             d.setTime(d.getTime() + (exdays*24*60*60*1000));
#             var expires = "expires="+ d.toUTCString();
#             document.cookie = cname + "=" + cvalue + ";" + expires + ";path=/";
#         }
#     </script>
# <noscript>
# <div id="javaScriptWarning" style="width: 100%; position:fixed; bottom: 0; left:0;z-index:1000;">
# <div style="background-color: #222;opacity:0.9;color: #FFFFFF;font-size: 13px;margin: 0 auto;padding: 8px;text-align: center;line-height:18px;">
#                             Javascript не активен. <br/> Пожалуйста, активируйте Javascript в браузере, иначе будут доступны не все функции сайта.
#                         </div>
# </div>
# </noscript>
# <script>(function (init)
# {
#     var root = document.getElementsByTagName('html')[0];
#     root.setAttribute('debug-cms', true);
#     root.setAttribute('debug-shoptext', true);
#
#         })();</script><div id="status200"></div></body>
# </html>

# %%
# Поиск по тегу <div>
result = soup.find_all('div', ('class','product-box-container'))

# %%
len(result)
# Out:
# 24

# %%
type(result)
# Out:
# bs4.element.ResultSet

# %% [markdown]
# ### Скрейпинг ссылок на каждый товар

# %%
# Первая часть ссылки
url_1 = 'https://apteka.de'

# %%
# Извлечение списка относительных ссылок на товары
url_2 = []
for i in result:
  for link in i.find_all('div', ('class','product-box__image')):
    url_2.append(link.find('a').get('href'))

# %%
len(url_2)
# Out:
# 24

# %%
url_2
# Out:
# ['/online-kaufen/allegra-allergietabletten-20-mg-18113489',
#  '/online-kaufen/allergodil-akut-forte-1-5-mg-ml-nasenspray-loesung-17510656',
#  '/online-kaufen/vividrin-azelastin-edo-bei-heuschnupfen-und-allergien-17538554',
#  '/online-kaufen/desloratadin-adgc-5-mg-filmtabletten-17145955',
#  '/online-kaufen/desloratadin-adgc-5-mg-filmtabletten-17145949',
#  '/online-kaufen/desloratadin-adgc-5-mg-filmtabletten-17145932',
#  '/online-kaufen/abtei-meersalz-nasen-spray-16893833',
#  '/online-kaufen/desloratadin-heumann-5-mg-filmtabletten-16938180',
#  '/online-kaufen/desloratadin-heumann-5-mg-filmtabletten-16938174',
#  '/online-kaufen/desloratadin-heumann-5-mg-filmtabletten-16938145',
#  '/online-kaufen/desloratadin-heumann-5-mg-filmtabletten-16908368',
#  '/online-kaufen/allvent-intens-kapseln-16881391',
#  '/online-kaufen/levocetirizin-micro-labs-5-mg-filmtabletten-16821029',
#  '/online-kaufen/levocetirizin-micro-labs-5-mg-filmtabletten-16821012',
#  '/online-kaufen/levocetirizin-micro-labs-5-mg-filmtabletten-16821006',
#  '/online-kaufen/mometason-beta-heuschnupfenspray-14374141',
#  '/online-kaufen/mometason-beta-heuschnupfenspray-14374112',
#  '/online-kaufen/desloratadin-glenmark-5-mg-tabletten-16605320',
#  '/online-kaufen/desloratadin-stada-5-mg-filmtabletten-16610048',
#  '/online-kaufen/desloratadin-stada-5-mg-filmtabletten-16610031',
#  '/online-kaufen/desloratadin-stada-5-mg-filmtabletten-16610025',
#  '/online-kaufen/levoceti-abz-5-mg-filmtabletten-bei-allergien-15318825',
#  '/online-kaufen/levoceti-abz-5-mg-filmtabletten-bei-allergien-15318819',
#  '/online-kaufen/levoceti-abz-5-mg-filmtabletten-bei-allergien-15318802']

# %%
import urllib.parse

# %%
# Объединение двух частей ссылки в абсолютный путь и создание списка со ссылками на каждый товар, расположенный на странице
url_joined = []

for link in url_2:
  url_joined.append(urllib.parse.urljoin(url_1, link))

# %%
url_joined
# Out:
# ['https://apteka.de/online-kaufen/allegra-allergietabletten-20-mg-18113489',
#  'https://apteka.de/online-kaufen/allergodil-akut-forte-1-5-mg-ml-nasenspray-loesung-17510656',
#  'https://apteka.de/online-kaufen/vividrin-azelastin-edo-bei-heuschnupfen-und-allergien-17538554',
#  'https://apteka.de/online-kaufen/desloratadin-adgc-5-mg-filmtabletten-17145955',
#  'https://apteka.de/online-kaufen/desloratadin-adgc-5-mg-filmtabletten-17145949',
#  'https://apteka.de/online-kaufen/desloratadin-adgc-5-mg-filmtabletten-17145932',
#  'https://apteka.de/online-kaufen/abtei-meersalz-nasen-spray-16893833',
#  'https://apteka.de/online-kaufen/desloratadin-heumann-5-mg-filmtabletten-16938180',
#  'https://apteka.de/online-kaufen/desloratadin-heumann-5-mg-filmtabletten-16938174',
#  'https://apteka.de/online-kaufen/desloratadin-heumann-5-mg-filmtabletten-16938145',
#  'https://apteka.de/online-kaufen/desloratadin-heumann-5-mg-filmtabletten-16908368',
#  'https://apteka.de/online-kaufen/allvent-intens-kapseln-16881391',
#  'https://apteka.de/online-kaufen/levocetirizin-micro-labs-5-mg-filmtabletten-16821029',
#  'https://apteka.de/online-kaufen/levocetirizin-micro-labs-5-mg-filmtabletten-16821012',
#  'https://apteka.de/online-kaufen/levocetirizin-micro-labs-5-mg-filmtabletten-16821006',
#  'https://apteka.de/online-kaufen/mometason-beta-heuschnupfenspray-14374141',
#  'https://apteka.de/online-kaufen/mometason-beta-heuschnupfenspray-14374112',
#  'https://apteka.de/online-kaufen/desloratadin-glenmark-5-mg-tabletten-16605320',
#  'https://apteka.de/online-kaufen/desloratadin-stada-5-mg-filmtabletten-16610048',
#  'https://apteka.de/online-kaufen/desloratadin-stada-5-mg-filmtabletten-16610031',
#  'https://apteka.de/online-kaufen/desloratadin-stada-5-mg-filmtabletten-16610025',
#  'https://apteka.de/online-kaufen/levoceti-abz-5-mg-filmtabletten-bei-allergien-15318825',
#  'https://apteka.de/online-kaufen/levoceti-abz-5-mg-filmtabletten-bei-allergien-15318819',
#  'https://apteka.de/online-kaufen/levoceti-abz-5-mg-filmtabletten-bei-allergien-15318802']

# %% [markdown]
# ### Извлечение данных одного товара

# %%
# Ссылка на первый товар
first_link = url_joined[0]

# %%
# GET-запрос серверу
response = requests.get(first_link)

# %%
# Парсинг данных
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ru">
# <head>
# <script>
#     let cookiesAccepted = document.cookie.indexOf("cookie-policy-accepted") != -1;
#     let month = new Array("Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct", "Nov", "Dec");
#     let days = new Array("Sun","Mon","Tue","Wed","Thu","Fri","Sat");
#     let date = new Date();
#     let expiration = new Date(date.setDate(date.getDate() + 365));
#
#     if ( ! cookiesAccepted) {
#         document.cookie = 'cc_analytics=false; expires='+ days[expiration.getDay()] +', '+ expiration.getDate() +' '+ month[expiration.getMonth()] +' '+ expiration.getFullYear() +' '+ expiration.getHours() +':'+ expiration.getMinutes() +':'+ expiration.getSeconds() +' UTC; path=/';
#         document.cookie = 'cc_advertising=false; expires='+ days[expiration.getDay()] +', '+ expiration.getDate() +' '+ month[expiration.getMonth()] +' '+ expiration.getFullYear() +' '+ expiration.getHours() +':'+ expiration.getMinutes() +':'+ expiration.getSeconds() +' UTC; path=/';
#     }
# </script>
# <title>Allegra Allergietabletten 20 mg 20 St - Диабет - apteka | Лекарства из Германии в Apteka.de</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="global" name="distribution">
# <meta content="Заказать лекарства из Германии с доставкой по Москве и России. Интернет аптека Германии. Apteka.de" name="description"/>
# <meta content="аптека купить лекарства медикаменты германия заказать онлайн доставка" name="keywords"/>
# <meta content="Mauve Webshopsystem 3" name="generator"/>
# <meta content="3 Days" name="revisit-after"/>
# <meta content="9e571d2e04b1a424" name="yandex-verification">
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="index,follow" name="robots"/>
# <link href="https://apteka.de/online-kaufen/allegra-allergietabletten-20-mg-18181918" rel="canonical"/>
# <link href="/assets/master/tmp/main.min.96d9bd93.css" rel="stylesheet" type="text/css"/>
# <script src="/assets/master/js/src/available.js" type="text/javascript"></script>
# <script>
#     window.meshop = {"customer":{"signedIn":false},"form":{"titles":{"1":{"titleId":"1","name":"\u0413\u043e\u0441\u043f\u043e\u0434\u0438\u043d"},"2":{"titleId":"2","name":"\u0413\u043e\u0441\u043f\u043e\u0436\u0430"},"3":{"titleId":"3","name":"\u0421\u0435\u043c\u044c\u044f"},"4":{"titleId":"4","name":"\u0424\u0438\u0440\u043c\u0430"}}}};
# </script><style type="text/css">#content {
#     max-width: 100%;
# }
#
# html[debug-cms=true] [debug="cms"] {
#     border: 2px solid #71b263 !important;
#     min-height: 20px;
# }
#
# html[debug-cms=true] [debug="cms"]::after {
#     content: "";
#     display: table;
#     clear: both;
# }
#
# html[debug-cms=true] [debug="cms"]:hover {
#     box-shadow: 0px 2px 20px rgba(0,0,0,.7);
#     position: relative;
#     z-index: 9998;
# }
#
# html[debug-cms=true] [debug="cms"]:hover {
#     border: 2px solid #54b200 !important;
# }
#
# html[debug-cms=true] [debug="cms"]:hover::before {
#     content: attr(data-params);
#     display: inline-block;
#     position: absolute;
#     left: 0;
#     top: 0;
#     z-index: 9999;
#     background-color: #54b200 !important;
#     color: #fff !important;
#     padding: 5px;
#     word-break: break-all;
# }
#
# html[debug-cms=true] [debug="cms"] [debug="cms"]:hover::before {
#     content: attr(data-params);
#     display: inline-block;
#     position: absolute;
#     right: 0;
#     bottom: 0;
#     left:auto;
#     top:auto;
#     z-index: 9999;
#     background-color: #EC7007 !important;
#     color: #fff !important;
#     padding: 5px;
#     word-break: break-all;
# }
# html[debug-cms=true] [debug="cms"] [debug="cms"],
# html[debug-cms=true] [debug="cms"] [debug="cms"]:hover{
#     border: 2px solid #EC7007 !important;
# }
#
# [debug="shoptext"] {
#     text-decoration: none !important;
#     border: 0 !important;
# }
#
# html[debug-shoptext=true] [debug="shoptext"] {
#     outline: 2px solid #ab65b2 !important;
#     position: relative;
# }
#
# html[debug-shoptext=true] [debug="shoptext"]:hover {
#     outline: 2px solid #833db2 !important;
#     z-index: 9999;
# }
#
# html[debug-shoptext=true] [debug="shoptext"]:hover::after {
#     background-color: #833db2 !important;
#     content: attr(title);
#     color: #fff !important;
#     position: absolute;
#     left: 0;
#     top: 0;
#     z-index: 9999;
#     padding-left: 2px;
#     padding-right: 2px;
#     font-size: 12px;
#     line-height: 1.2;
# }
# </style><script>
#   window.dataLayer = window.dataLayer || []
#
#   function eventPush (event) {
#     if (typeof window.gtag !== 'undefined') {
#       gtag('event', event.event, event)
#     } else {
#       window.dataLayer.push(event)
#     }
#   }
#
#     window.dataLayer.push({"cart_items":[]})
#
#       eventPush({"event":"view_item","currency":"EUR","value":6.55,"value_gross":7.79,"items":[{"item_id":"18113489","item_name":"Allegra Allergietabletten 20 mg","item_brand":"A. Nattermann & Cie GmbH","item_category":"\u0410\u043b\u043b\u0435\u0440\u0433\u0438\u044f \u0438 \u0430\u043b\u043b\u0435\u0440\u0433\u0438\u0447\u0435\u0441\u043a\u0438\u0439 \u0440\u0438\u043d\u0438\u0442","item_category_id":"1","price":6.55,"price_gross":7.79,"quantity":1}]})
#   </script>
# <script>
#     (function (w, d, s, l, i) {
#         w[l] = w[l] || [];
#         w[l].push({'gtm.start': new Date().getTime(), event: 'gtm.js'});
#         var f = d.getElementsByTagName(s)[0], j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
#         j.async = true;
#         j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#         f.parentNode.insertBefore(j, f);
#     })(window, document, 'script', 'dataLayer', 'GTM-K2FC265');
# </script></meta></meta></head>
# <body class="">
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-K2FC265" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <div id="app">
# <header>
# <div class="promotion-banner relative bg-primary text-white text-center px-3 py-2 hide">
# <div class="inline-block lg:ml-22">
# <span class="inline-block mb-2">
# <p><b>В связи с актуальной ситуацией отправка пакетов на Украину, в Россию и в Белоруссию, а также оформление заказов из этих стран, к сожалению невозможны.</b></p>
# </span>
# <a class="button-light ml-2" href="/versandkosten">Mehr</a>
# </div>
# <a class="absolute text-white flex items-center pin-r pin-y mr-3 ml-4" href="#">
# <span class="promotion-close">x</span>
# </a>
# </div>
# <aside class="header_topbar">
# <div class="container container--wide">
# <div class="flex pt-3 pb-2 items-center justify-between border-b border-grey">
# <div class="hidden-print">
# </div>
# <div class="text-center md:text-right">
# </div>
# <div></div>
# </div>
# </div>
# </aside>
# <div class="sticky pin-t z-10 md:relative container container--wide px-0">
# <div class="md:bg-transparent mx-auto flex flex-wrap md:flex-no-wrap items-center p-3 md:py-3 lg:pr-6 w-full justify-between flex-row">
# <a class="block w-64 sm:w-auto sm:max-w-full" href="https://apteka.de/" title="Стартовая страница">
# <img alt="Logo" src="/documents/logo/Logo Apteka 282x66.png"/>
# </a>
# <div class="user-nav md:order-last flex my-3 md:my-0">
# <a @click.prevent="emitEvent('offcanvas_open_account')" class="-ml-2 sm:-ml-0 text-xs text-center w-20 sm:w-auto text-grey-darker px-1 sm:px-2 lg:px-4 mx-1 sm:mx-0 icon-nav hover:text-primary" href="https://apteka.de/account/login" title="Зарегистрируйтесь здесь.">
# <div class="sm:w-16 m-auto">
# <img class="icon-nav__hover w-16" src="/assets/master/img/design/icons/icon-login-hover.svg"/><img class="icon-nav__regular w-16" src="/assets/master/img/design/icons/icon-login.svg"/>
# </div>
# <div class="hidden sm:block">Войти</div>
# </a>
# <a class="-ml-2 sm:-ml-0 text-xs text-center w-20 sm:w-auto text-grey-darker px-1 sm:px-2 lg:px-4 mx-1 sm:mx-0 icon-nav hover:text-primary relative" href="https://apteka.de/notepad">
# <div class="sm:w-16 m-auto">
# <img class="icon-nav__hover w-16" src="/assets/master/img/design/icons/icon-merkzettel-hover.svg?v=1"/><img class="icon-nav__regular w-16" src="/assets/master/img/design/icons/icon-merkzettel.svg"/>
# </div>
# <div class="hidden sm:block">Список отложенных товаров</div>
# </a>
# <a class="-ml-2 sm:-ml-0 text-xs text-center w-20 sm:w-auto text-grey-darker px-1 sm:px-2 lg:px-4 mx-1 sm:mx-0 icon-nav hover:text-primary lg:pr-0 relative" href="https://apteka.de/checkout/cart">
# <mini-cart class="text-sm"></mini-cart>
# <div class="sm:w-16 m-auto">
# <img class="icon-nav__hover w-16" src="/assets/master/img/design/icons/icon-cart-hover.svg"/><img class="icon-nav__regular w-16" src="/assets/master/img/design/icons/icon-cart.svg"/>
# </div>
# <div class="hidden sm:block">Корзина</div>
# </a>
# <a class="-ml-2 sm:-ml-0 text-xs text-center w-20 sm:w-auto text-grey-darker px-1 sm:px-2 lg:px-4 mx-1 sm:mx-0 icon-nav hover:text-primary lg:hidden flex flex-col justify-between -mr-1 sm:-mr-0 pr-0" href="#mobileNavigation" id="mobileNavigationButton" title="Все категории">
# <i class="fa fa-bars text-5xl mt-1" id="mobileNavigationIcon"></i>
# <div class="hidden sm:block">МЕНЮ</div>
# </a>
# </div>
# <speedfinder-search :is-primary="true" :is-products-only="false" :min-search-text-length="speedfinder.minSearchTextLength" :overwrite-search-term="speedfinder.searchTerm" @speedfinder_search_term_changed="onSpeedfinderSearchTermChange" class="w-full h-16 xl:ml-16 md:h-24 md:max-w-sm lg:max-w-md xl:max-w-lg">
# <form action="https://apteka.de/suche.html" class="w-full h-16 xl:ml-16 md:h-24" method="GET">
# <div class="relative bg-white z-10 flex shadow-md h-full">
# <input autocomplete="off" class="w-full pl-3" maxlength="128" name="term" placeholder="Товар, фармацевтический номер, действующее вещество..." type="text"/>
# <button class="bg-grey-light-dark hover:bg-grey-light-darker text-white text-base md:text-4xl m-0 px-4" tabindex="-1" type="submit" value="1">
# <i class="fa fa-search"></i>
# </button>
# </div>
# </form>
# </speedfinder-search>
# </div>
# </div>
# <div class="bg-grey">
# <div class="container container--mid relative page-wrap-top hidden sm:block">
# <img class="absolute pin-r -mt-2 hidden lg:block" src="/assets/master/img/design/apotheken-a-rund.png" style="z-index: 1;"/>
# <nav class="navmenu c-navmenu py-3 hidden-xs hidden-sm hidden-print">
# <ul class="o-nav o-nav__level o-nav__level--1 o-nav--inline"><li class="o-nav__item o-nav__item--has-children"><a href="/online-shop" title="Все категории">Все категории</a>
# <ul class="o-nav o-nav__level o-nav__level--2"><li class="o-nav__item"><a class="active" href="/online-shop/allergie-heuschnupfen" title="Аллергия и аллергический ринит">Аллергия и аллергический ринит</a></li><li class="o-nav__item"><a href="/online-shop/alles-fuer-die-frau" title="Все для женщин">Все для женщин</a></li><li class="o-nav__item"><a href="/online-shop/augen-nase-ohren" title="Глаза, нос, уши">Глаза, нос, уши</a></li><li class="o-nav__item"><a href="/online-shop/augenpflege" title="Уход за глазами">Уход за глазами</a></li><li class="o-nav__item"><a href="/online-shop/buecher-cd-dvd" title="Книги, CD и DVD">Книги, CD и DVD</a></li><li class="o-nav__item"><a href="/online-shop/diabetes" title="Диабет">Диабет</a></li><li class="o-nav__item"><a href="/online-shop/erkaeltung-abwehr" title="Простуда и профилактика">Простуда и профилактика</a></li><li class="o-nav__item"><a href="/online-shop/familie" title="Семья">Семья</a></li><li class="o-nav__item"><a href="/online-shop/fitness" title="Фитнес">Фитнес</a></li><li class="o-nav__item"><a href="/online-shop/geschenkideen" title="Идеи для подарков">Идеи для подарков</a></li><li class="o-nav__item"><a href="/online-shop/haus-reiseapotheke" title="Домашняя аптечка и аптечка для путешествий">Домашняя аптечка и аптечка для путешествий</a></li><li class="o-nav__item"><a href="/online-shop/haeusliche-pflege" title="Медицинская помощь на дому">Медицинская помощь на дому</a></li><li class="o-nav__item"><a href="/online-shop/haut-haare-naegel" title="Кожа, волосы, ногти">Кожа, волосы, ногти</a></li><li class="o-nav__item"><a href="/online-shop/herz-kreislauf-venen" title="Сердце, система кровообращения и вены">Сердце, система кровообращения и вены</a></li><li class="o-nav__item"><a href="/online-shop/kosmetik" title="Косметика">Косметика</a></li><li class="o-nav__item"><a href="/online-shop/magen-darm-verdauung" title="Желудок, кишечник и пищеварение">Желудок, кишечник и пищеварение</a></li><li class="o-nav__item"><a href="/online-shop/marken" title="Марки">Марки</a></li><li class="o-nav__item"><a href="/online-shop/medizinische-geraete" title="Медицинские приборы">Медицинские приборы</a></li><li class="o-nav__item"><a href="/online-shop/muskeln-knochen-gelenke" title="Мышцы, кости и суставы">Мышцы, кости и суставы</a></li><li class="o-nav__item"><a href="/online-shop/nahrungsergaenzung" title="Пищевые добавки">Пищевые добавки</a></li><li class="o-nav__item"><a href="/online-shop/natur-pflanzenheilkunde" title="Натуральные и растительные лекарственные средства">Натуральные и растительные лекарственные средства</a></li><li class="o-nav__item"><a href="/online-shop/nerven-beruhigung-schlaf" title="Средства для нервной системы, успокоения и хорошего сна">Средства для нервной системы, успокоения и хорошего сна</a></li><li class="o-nav__item"><a href="/online-shop/neu-im-sortiment" title="Новое в ассортименте">Новое в ассортименте</a></li><li class="o-nav__item"><a href="/online-shop/niere-blase-prostata" title="Почки, мочевой пузырь и простата">Почки, мочевой пузырь и простата</a></li><li class="o
# <ul class="o-nav o-nav__level o-nav__level--2"><li class="o-nav__item"><a href="/online-shop/wellness/aromatherapie" title="Ароматерапия">Ароматерапия</a></li><li class="o-nav__item"><a href="/online-shop/wellness/bad-sauna" title="Ванна и сауна">Ванна и сауна</a></li><li class="o-nav__item"><a href="/online-shop/wellness/bonbons" title="Леденцы">Леденцы</a></li><li class="o-nav__item"><a href="/online-shop/wellness/massage" title="Массаж">Массаж</a></li><li class="o-nav__item"><a href="/online-shop/wellness/struempfe-einlagen" title="Чулки и стельки">Чулки и стельки</a></li><li class="o-nav__item"><a href="/online-shop/wellness/waermflaschen-kissen" title="Грелки и греющие подушки ">Грелки и греющие подушки </a></li></ul>
# </li></ul>
# </nav>
# </div>
# </div>
# </header>
# <div>
# <div class="container my-2">
# </div>
# </div>
# <main class="section-main container page-wrap-bottom">
# <ol class="breadcrumb bg-transparent">
# <li><a class="text-grey-darker hover:text-grey-dark text-sm" href="https://apteka.de/" title="Стартовая страница">Стартовая страница</a></li>
# <li><a class="text-grey-darker hover:text-grey-dark text-sm" href="/online-shop/allergie-heuschnupfen" title="Аллергия и аллергический ринит">Аллергия и аллергический ринит</a></li>
# <li class="active text-grey-darker text-sm">Allegra Allergietabletten 20 mg</li>
# </ol>
# <div class="row">
# <div class="col-xs-12">
# <div id="ajaxProduct">
# <div class="row" id="details">
# <div class="col-sm-6 hidden-xs hidden-print">
# <div class="text-center">
# <div class="product-photo hidden-print">
# <div class="bg-primary text-white flex flex-col justify-between text-center leading-none absolute pin-t z-1 rounded-full mt-3 mr-3 pin-r w-24 h-24 text-base">
# <span class="my-auto">-36 %<sup>1</sup></span>
# </div>
# <a @click.prevent="modal('modal672c8ce220de5')" href="/documents/products/Zoom/1011719058.jpg" title="Allegra Allergietabletten 20 mg">
# <img alt="Allegra Allergietabletten 20 mg" id="image946185" src="/documents/products/Detailansicht/1011719058.jpg" title="Allegra Allergietabletten 20 mg">
# </img></a>
# <modal modal-id="modal672c8ce220de5" title="Allegra Allergietabletten 20 mg">
# <div slot="body"><img alt="Allegra Allergietabletten 20 mg" src="/documents/products/Zoom/1011719058.jpg"/></div>
# </modal>
# <div class="moreillustrations">
# <h3 class="text-left">Больше изображений</h3>
# <div align="center" class="inlay">
# <a @click.prevent="modal('modal672c8ce220e7c')" href="/documents/products/Zoom/1011719058.jpg" title="Allegra Allergietabletten 20 mg"><img border="1" height="50" src="/documents/products/Zoom/1011719058.jpg"/></a>
# <modal modal-id="modal672c8ce220e7c">
# <div slot="body"><img alt="Allegra Allergietabletten 20 mg" src="/documents/products/Zoom/1011719058.jpg"/></div>
# </modal>
# <a @click.prevent="modal('modal672c8ce220e87')" href="/documents/products/Zoom/1011719061.jpg" title="Allegra Allergietabletten 20 mg"><img border="1" height="50" src="/documents/products/Zoom/1011719061.jpg"/></a>
# <modal modal-id="modal672c8ce220e87">
# <div slot="body"><img alt="Allegra Allergietabletten 20 mg" src="/documents/products/Zoom/1011719061.jpg"/></div>
# </modal>
# <a @click.prevent="modal('modal672c8ce220e8c')" href="/documents/products/Zoom/1012148190.jpg" title="Allegra Allergietabletten 20 mg"><img border="1" height="50" src="/documents/products/Zoom/1012148190.jpg"/></a>
# <modal modal-id="modal672c8ce220e8c">
# <div slot="body"><img alt="Allegra Allergietabletten 20 mg" src="/documents/products/Zoom/1012148190.jpg"/></div>
# </modal>
# <a @click.prevent="modal('modal672c8ce220e91')" href="/documents/products/Zoom/1011719077.jpg" title="Allegra Allergietabletten 20 mg"><img border="1" height="50" src="/documents/products/Zoom/1011719077.jpg"/></a>
# <modal modal-id="modal672c8ce220e91">
# <div slot="body"><img alt="Allegra Allergietabletten 20 mg" src="/documents/products/Zoom/1011719077.jpg"/></div>
# </modal>
# </div>
# <p> </p>
# </div>
# </div>
# </div>
# <p class="text-xs">Изображение схожее</p>
# </div>
# <div class="col-sm-6">
# <div class="bg-grey-light">
# <div class="p-4 pb-3 sm:pb-4">
# <h1 class="h2 mt-0 sm:mb-6"><span>Allegra Allergietabletten 20 mg</span> 20 St</h1>
# <div class="hidden-lg hidden-md hidden-sm mb-2">
# <div class="row">
# <div class="col-xs-12 col-sm-5 col-lg-8 col-sm-offset-3">
# <div class="product-photo hidden-print">
# <div class="bg-primary text-white flex flex-col justify-between text-center leading-none absolute pin-t z-1 rounded-full mt-3 mr-3 pin-r w-24 h-24 text-base">
# <span class="my-auto">-36 %<sup>1</sup></span>
# </div>
# <a @click.prevent="modal('modal672c8ce220fea')" href="/documents/products/Zoom/1011719058.jpg" title="Allegra Allergietabletten 20 mg">
# <img alt="Allegra Allergietabletten 20 mg" id="image946185" src="/documents/products/Detailansicht/1011719058.jpg" title="Allegra Allergietabletten 20 mg">
# </img></a>
# <modal modal-id="modal672c8ce220fea" title="Allegra Allergietabletten 20 mg">
# <div slot="body"><img alt="Allegra Allergietabletten 20 mg" src="/documents/products/Zoom/1011719058.jpg"/></div>
# </modal>
# <div class="moreillustrations">
# <h3 class="text-left">Больше изображений</h3>
# <div align="center" class="inlay">
# <a @click.prevent="modal('modal672c8ce221057')" href="/documents/products/Zoom/1011719058.jpg" title="Allegra Allergietabletten 20 mg"><img border="1" height="50" src="/documents/products/Zoom/1011719058.jpg"/></a>
# <modal modal-id="modal672c8ce221057">
# <div slot="body"><img alt="Allegra Allergietabletten 20 mg" src="/documents/products/Zoom/1011719058.jpg"/></div>
# </modal>
# <a @click.prevent="modal('modal672c8ce221060')" href="/documents/products/Zoom/1011719061.jpg" title="Allegra Allergietabletten 20 mg"><img border="1" height="50" src="/documents/products/Zoom/1011719061.jpg"/></a>
# <modal modal-id="modal672c8ce221060">
# <div slot="body"><img alt="Allegra Allergietabletten 20 mg" src="/documents/products/Zoom/1011719061.jpg"/></div>
# </modal>
# <a @click.prevent="modal('modal672c8ce221066')" href="/documents/products/Zoom/1012148190.jpg" title="Allegra Allergietabletten 20 mg"><img border="1" height="50" src="/documents/products/Zoom/1012148190.jpg"/></a>
# <modal modal-id="modal672c8ce221066">
# <div slot="body"><img alt="Allegra Allergietabletten 20 mg" src="/documents/products/Zoom/1012148190.jpg"/></div>
# </modal>
# <a @click.prevent="modal('modal672c8ce221070')" href="/documents/products/Zoom/1011719077.jpg" title="Allegra Allergietabletten 20 mg"><img border="1" height="50" src="/documents/products/Zoom/1011719077.jpg"/></a>
# <modal modal-id="modal672c8ce221070">
# <div slot="body"><img alt="Allegra Allergietabletten 20 mg" src="/documents/products/Zoom/1011719077.jpg"/></div>
# </modal>
# </div>
# <p> </p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="flex flex-wrap -mx-3">
# <div class="w-full sm:w-1/2 px-3 mb-2 sm:mb-4">
# <div class="information mb-3">
#                                     Zur Anwendung bei allergisch bedingten Symptome wie Niesen, tränende Augen sowie Juckreiz und Rötungen. Für Kinder ab 12 Jahren und Erwachsene.
#                                 </div>
# <div class="font-sari">
#                                 Форма выпуска: Tabletten
#                             </div>
# <div>
# <span class="font-sari">Содержание:</span> 20 St
#                         </div>
# <div>
# <span class="font-sari">Фармацевтический номер:</span> 18113489
#                                 </div>
# <div class="font-sari">
#                                     Производитель: A. Nattermann &amp; Cie GmbH
#                                 </div>
# </div>
# <div class="w-full sm:w-1/2 px-3">
# <div>
# <p class="price-details text-grey-darker text-4xl font-sans font-bold mb-0">
# <span class="text-secondary">7,79 €</span>
# <span class="small">
# <span class="saving text-sm text-grey-darker font-normal">вместо 12,20 €
#
#                     UVP
#                 </span>
# </span>
# </p>
# </div>
# <p class="small">
#                                                                     Вкл. НДС"
#                                                                 при необходимости включая <a data-target="#content-modal" data-title="Versandkosten" data-toggle="content-modal" href="/ajax/content/versandkosten.20005.html" rel="nofollow">стоимость доставки</a>
# </p>
# <p> <img alt="в наличии" class="delivery-time-image" src="/documents/delivery_times/delivery-three.png" title="в наличии"> <small> в наличии</small></img></p>
# <p>
# <a class="text-grey-darker hover:text-grey-dark underline" href="/documents/products/PDF/1012554935.pdf" target="_blank">
# <i aria-hidden="true" class="fa fa-file-pdf-o fa-fw mr-1"></i>1012554935
#                                         </a>
# </p>
# <div class="productActions hidden-print">
# <p><a href="https://apteka.de/productrating/946185"><i class="fa fa-fw fa-star"></i> Оценки</a></p>
# </div>
# </div>
# </div>
# </div>
# <div>
# <div class="hidden-print">
# <form @submit.prevent="emitEvent('cart_update', $event)" action="https://apteka.de/checkout/cart/add/product/946185" id="prod946185" method="post">
# <input name="options[PrescriptionType]" type="hidden" value="0">
# <input name="product[product_id]" type="hidden" value="946185"/>
# <div class="flex">
# <a class="addToNotepad px-4 flex" data-id="946185" href="">
# <div class="my-auto">
# <img class="icon-nav__regular" src="/assets/master/img/design/icons/icon-merkzettel.png" width="50px"/>
# </div>
# </a>
# <div class="quantity-picker flex bg-white">
# <button @click.prevent="stepDown('quantity672c8ce221e4a')" class="quantity-picker__minus text-grey-dark" href="#" type="button">
# <i class="fa fa-minus"></i>
# </button>
# <input autocomplete="off" class="quantity-picker__field text-grey-dark" id="quantity672c8ce221e4a" min="1" name="product[quantity]" step="1" type="number" value="1"/>
# <button @click.prevent="stepUp('quantity672c8ce221e4a')" class="quantity-picker__plus text-grey-dark" href="#" type="button">
# <i class="fa fa-plus"></i>
# </button>
# </div>
# <button class="bg-secondary hover:bg-secondary-light text-white font-sari px-2 sm:px-4 py-2 sm:py-3 w-full flex justify-between" name="refresh_submit" type="submit">
# <span class="flex-no-shrink">
# <img class="inline" src="/assets/master/img/design/icons/icon-cart-white.png" width="30px"/>
# </span>
# <span class="m-auto">В корзину</span>
# </button>
# </div>
# </input></form>
# </div>
# </div>
# </div>
# </div>
# <div class="clearfix"></div>
# </div>
# <div class="hidden-lg hidden-md hidden-sm mt-2 mb-2">
# <p class="text-xs">Изображение схожее</p>
# </div>
# <div class="row flex flex-col-reverse xl:flex-row">
# <div class="col-lg-6 hidden-print">
# <div class="variantsborder">
# <h2 class="h2 text-primary mb-6">Подходящие товары:</h2>
# <div class="row">
# <div class="col-xs-12 mb-4">
# <div class="package-size-product border-b md:border-0 border-grey pb-4 md:pb-0">
# <form @submit.prevent="emitEvent('cart_update', $event)" action="https://apteka.de/checkout/cart/add/product/946278" class="add-product flex flex-col md:flex-row justify-between" id="prod946278" method="post">
# <div>
# <img class="mr-4" src="/documents/products/Listenansicht/1011719067.jpg" style="width: 50px;"/>
# </div>
# <a class="block mr-4 mb-2 md:mb-0 text-grey-darker hover:text-primary" href="/online-kaufen/allegra-allergietabletten-20-mg-18181918">
# <div>Allegra Allergietabletten 20 mg</div>
# <div class="text-xs">Tabletten</div>
# <div class="text-xs">6 St</div>
# </a>
# <div class="w-48">
# <input name="product[product_id]" type="hidden" value="946278"/>
# <input name="product[quantity]" type="hidden" value="1"/>
# <input name="options[PrescriptionType]" type="hidden" value="0"/>
# <div class="price-info mb-2 md:mb-0">
# <div class="price text-grey-darker">
# <span class="text-grey-darker">5,22 € <span class="small">inkl. MwSt.</span></span>
# </div>
# <div class="description">
# <div>
# </div>
# </div>
# </div>
# </div>
# <div>
# <button class="md:ml-4">
# <img class="inline" src="/assets/master/img/design/icons/icon-cart-hover.png" width="30px"/>
# </button>
# </div>
# </form>
# </div>
# </div>
# <div class="col-xs-12 mb-4">
# <div class="package-size-product border-b md:border-0 border-grey pb-4 md:pb-0">
# <form @submit.prevent="emitEvent('cart_update', $event)" action="https://apteka.de/checkout/cart/add/product/946186" class="add-product flex flex-col md:flex-row justify-between" id="prod946186" method="post">
# <div>
# <div class="bg-primary text-white flex flex-col justify-between text-center leading-none absolute pin-t z-1 rounded-full md:mr-3 ml-2 md:ml-0 pin-l w-12 h-12 text-xs">
# <span class="my-auto">-35 %<sup>1</sup></span>
# </div>
# <img class="mr-4" src="/documents/products/Listenansicht/1011719070.jpg" style="width: 50px;"/>
# </div>
# <a class="block mr-4 mb-2 md:mb-0 text-grey-darker hover:text-primary" href="/online-kaufen/allegra-allergietabletten-20-mg-18113578">
# <div>Allegra Allergietabletten 20 mg</div>
# <div class="text-xs">Tabletten</div>
# <div class="text-xs">50 St</div>
# </a>
# <div class="w-48">
# <input name="product[product_id]" type="hidden" value="946186"/>
# <input name="product[quantity]" type="hidden" value="1"/>
# <input name="options[PrescriptionType]" type="hidden" value="0"/>
# <div class="price-info mb-2 md:mb-0">
# <div class="price text-grey-darker">
# <span class="text-secondary">17,99 € <span class="small">inkl. MwSt.</span></span>
# </div>
# <div class="description">
# <div class="text-xs">вместо
#                                                 27,74 €
#                                             </div>
# <div>
# </div>
# </div>
# </div>
# </div>
# <div>
# <button class="md:ml-4">
# <img class="inline" src="/assets/master/img/design/icons/icon-cart-hover.png" width="30px"/>
# </button>
# </div>
# </form>
# </div>
# </div>
# <div class="col-xs-12 mb-4">
# <div class="package-size-product border-b md:border-0 border-grey pb-4 md:pb-0">
# <form @submit.prevent="emitEvent('cart_update', $event)" action="https://apteka.de/checkout/cart/add/product/997870" class="add-product flex flex-col md:flex-row justify-between" id="prod997870" method="post">
# <div>
# <div class="bg-primary text-white flex flex-col justify-between text-center leading-none absolute pin-t z-1 rounded-full md:mr-3 ml-2 md:ml-0 pin-l w-12 h-12 text-xs">
# <span class="my-auto">-30 %<sup>1</sup></span>
# </div>
# <img class="mr-4" src="/documents/products/Listenansicht/1012555288.jpg" style="width: 50px;"/>
# </div>
# <a class="block mr-4 mb-2 md:mb-0 text-grey-darker hover:text-primary" href="/online-kaufen/allegra-allergietabletten-20-mg-18887647">
# <div>Allegra Allergietabletten 20 mg</div>
# <div class="text-xs">Tabletten</div>
# <div class="text-xs">100 St</div>
# </a>
# <div class="w-48">
# <input name="product[product_id]" type="hidden" value="997870"/>
# <input name="product[quantity]" type="hidden" value="1"/>
# <input name="options[PrescriptionType]" type="hidden" value="0"/>
# <div class="price-info mb-2 md:mb-0">
# <div class="price text-grey-darker">
# <span class="text-secondary">35,59 € <span class="small">inkl. MwSt.</span></span>
# </div>
# <div class="description">
# <div class="text-xs">вместо
#                                                 50,97 €
#                                             </div>
# <div>
# </div>
# </div>
# </div>
# </div>
# <div>
# <button class="md:ml-4">
# <img class="inline" src="/assets/master/img/design/icons/icon-cart-hover.png" width="30px"/>
# </button>
# </div>
# </form>
# </div>
# </div>
# </div>
# <div class="clearfix"></div>
# </div>
# </div>
# <div class="col-lg-6 hidden-xs hidden-print">
# <div class="my-4">
# <p class="text-xs">
# </p>
# </div>
# </div>
# </div>
# <div class="inlay"><strong>Wichtige Hinweise (Pflichtangaben):<br/><br/>Allegra Allergietabletten 20 mg Tabletten</strong>. Wirkstoff: Bilastin. Anwendungsgebiete: Antihistaminikum. Zur Linderung der Beschwerden allergischer Rhinokonjunktivitis und Urtikaria.<br/><br/><strong>Zu Risiken und Nebenwirkungen lesen Sie die Packungsbeilage und fragen Sie Ihre Ärztin, Ihren Arzt oder in Ihrer Apotheke.</strong><br/><br/><br/>GEBRAUCHSINFORMATION: INFORMATION FÜR PATIENTEN<br/><br/>Allegra Allergietabletten<br/>20 mg Tabletten<br/>Zur Anwendung bei Erwachsenen und Jugendlichen ab 12 Jahren<br/>Bilastin<br/><br/>Lesen Sie die gesamte Packungsbeilage sorgfältig durch, bevor Sie mit der Einnahme dieses Arzneimittels beginnen, denn sie enthält wichtige Informationen.<br/>Nehmen Sie dieses Arzneimittel immer genau wie in dieser Packungsbeilage beschrieben bzw. genau nach Anweisung Ihres Arztes oder Apothekers ein.<br/><br/><ul style="padding-left: 20px;"><li>Heben Sie die Packungsbeilage auf. Vielleicht möchten Sie diese später nochmals lesen.</li><li>Fragen Sie Ihren Apotheker, wenn Sie weitere Informationen oder einen Rat benötigen.</li><li>Wenn Sie Nebenwirkungen bemerken, wenden Sie sich an Ihren Arzt oder Apotheker. Dies gilt auch für Nebenwirkungen, die nicht in dieser Packungsbeilage angegeben sind. Siehe Abschnitt 4.</li><li>Wenn Sie sich nicht

# <div class="product-box__image text-center p-0 md:p-2">
# <a href="/online-kaufen/wick-inhalierstift-n-03225679" title="Wick Inhalierstift N">
# <img alt="Wick Inhalierstift N" src="/documents/products/Listenansicht/1010121971.jpg" style="margin: auto" title="Wick Inhalierstift N">
# </img></a>
# <div class="bg-primary text-white flex flex-col justify-between text-center leading-none absolute pin-t z-1 rounded-full mt-3 pin-r w-24 h-24 text-base">
# <span class="my-auto">-36 %<sup>1</sup></span>
# </div>
# </div>
# <div class="product-box__meta">
# <div class="productrating">
# </div>
# <h4 class="product-box__title mt-0 mb-2"><a class="text-grey-darker h4 text-base mb-0" href="/online-kaufen/wick-inhalierstift-n-03225679" title="Wick Inhalierstift N">Wick Inhalierstift N</a></h4>
# <div class="list-meta">
# <div>
# <span class="font-sari">Форма выпуска: Stifte</span>
# </div>
# <div>
# <span class="font-sari">Содержание:</span> 1 St
#                                     </div>
# <div>
# <span class="font-sari">Фармацевтический номер:</span> 03225679
#                                 </div>
# <div>
# <span class="font-sari">Производитель:</span> WICK Pharma - Zweigniederlassung der Procter &amp; Gamble GmbH
#                                                                     </div>
# <p class="delivery-time"> <img alt="в наличии" class="delivery-time-image" src="/documents/delivery_times/delivery-three.png" title="в наличии"> <small> в наличии</small></img></p>
# </div>
# </div>
# <div class="product-box__bottom">
# <div class="product-box__bottom__wrap text-grey-dark base-price-boxed">
#
#                                                                 1 St
#                                     <div class="pull-right">
# </div>
# </div>
# <div class="product-box__bottom__wrap">
# <div>
# <div class="line-through">
#                                         5,97 €
#                                     </div>
# </div>
# <div class="product-box__price">
# <div class="mb-0 text-base text-secondary">
#
#                                         3,79 €
#
#                                     </div>
# </div>
# <div class="base-price-list text-grey-dark">
# </div>
# <p class="small product-shipping-info">
#                                                                     Вкл. НДС"
#                                                                 при необходимости включая <a data-target="#content-modal" data-title="Versandkosten" data-toggle="content-modal" href="/ajax/content/versandkosten.20005.html" rel="nofollow">стоимость доставки</a>
# </p>
# </div>
# <form @submit.prevent="emitEvent('cart_update', $event)" action="https://apteka.de/checkout/cart/add/product" class="text-right flex-1 justify-end product-submit-form" method="post">
# <input name="product[product_id]" type="hidden" value="24536"/>
# <input name="options[PrescriptionType]" type="hidden" value="0"/>
# <div class="quantity-picker flex">
# <button @click.prevent="stepDown('quantity672c8ce223a7c')" class="quantity-picker__minus text-grey-dark" href="#" type="button">
# <i class="fa fa-minus"></i>
# </button>
# <input autocomplete="off" class="quantity-picker__field text-grey-dark" id="quantity672c8ce223a7c" min="1" name="product[quantity]" step="1" type="number" value="1"/>
# <button @click.prevent="stepUp('quantity672c8ce223a7c')" class="quantity-picker__plus text-grey-dark" href="#" type="button">
# <i class="fa fa-plus"></i>
# </button>
# </div>
# <button class="product-box__tocart text-white bg-secondary px-2 md:w-full" name="refresh_submit" title="В корзину" type="submit" value=""><i class="fa fa-shopping-cart"></i><span class="text-base"> добавлено в  корзину.</span></button>
# </form>
# </div>
# </div>
# </div>
# <div class="product-box-container flex col-sm-4 col-lg-3 col-xs-12 mb-4">
# <div class="bg-white product-box flex">
# <div class="product-box__image text-center p-0 md:p-2">
# <a href="/online-kaufen/ibuflam-akut-400-mg-filmtabletten-11648419" title="Ibuflam akut 400 mg Filmtabletten">
# <img alt="Ibuflam akut 400 mg Filmtabletten" src="/documents/products/Listenansicht/1007919338.jpg" style="margin: auto" title="Ibuflam akut 400 mg Filmtabletten">
# </img></a>
# <div class="bg-primary text-white flex flex-col justify-between text-center leading-none absolute pin-t z-1 rounded-full mt-3 pin-r w-24 h-24 text-base">
# <span class="my-auto">-40 %<sup>1</sup></span>
# </div>
# </div>
# <div class="product-box__meta">
# <div class="productrating">
# </div>
# <h4 class="product-box__title mt-0 mb-2"><a class="text-grey-darker h4 text-base mb-0" href="/online-kaufen/ibuflam-akut-400-mg-filmtabletten-11648419" title="Ibuflam akut 400 mg Filmtabletten">Ibuflam akut 400 mg Filmtabletten</a></h4>
# <div class="list-meta">
# <div>
# <span class="font-sari">Форма выпуска: Filmtabletten</span>
# </div>
# <div>
# <span class="font-sari">Содержание:</span> 50 St
#                                     </div>
# <div>
# <span class="font-sari">Фармацевтический номер:</span> 11648419
#                                 </div>
# <div>
# <span class="font-sari">Производитель:</span> A. Nattermann &amp; Cie GmbH
#                                                                     </div>
# <p class="delivery-time"> <img alt="в наличии" class="delivery-time-image" src="/documents/delivery_times/delivery-three.png" title="в наличии"> <small> в наличии</small></img></p>
# </div>
# </div>
# <div class="product-box__bottom">
# <div class="product-box__bottom__wrap text-grey-dark base-price-boxed">
#
#                                                                 50 St
#                                     <div class="pull-right">
# </div>
# </div>
# <div class="product-box__bottom__wrap">
# <div>
# <div class="line-through">
#                                         12,76 €
#                                     </div>
# </div>
# <div class="product-box__price">
# <div class="mb-0 text-base text-secondary">
#
#                                         7,65 €
#
#                                     </div>
# </div>
# <div class="base-price-list text-grey-dark">
# </div>
# <p class="small product-shipping-info">
#                                                                     Вкл. НДС"
#                                                                 при необходимости включая <a data-target="#content-modal" data-title="Versandkosten" data-toggle="content-modal" href="/ajax/content/versandkosten.20005.html" rel="nofollow">стоимость доставки</a>
# </p>
# </div>
# <form @submit.prevent="emitEvent('cart_update', $event)" action="https://apteka.de/checkout/cart/add/product" class="text-right flex-1 justify-end product-submit-form" method="post">
# <input name="product[product_id]" type="hidden" value="54295"/>
# <input name="options[PrescriptionType]" type="hidden" value="0"/>
# <div class="quantity-picker flex">
# <button @click.prevent="stepDown('quantity672c8ce223cd3')" class="quantity-picker__minus text-grey-dark" href="#" type="button">
# <i class="fa fa-minus"></i>
# </button>
# <input autocomplete="off" class="quantity-picker__field text-grey-dark" id="quantity672c8ce223cd3" min="1" name="product[quantity]" step="1" type="number" value="1"/>
# <button @click.prevent="stepUp('quantity672c8ce223cd3')" class="quantity-picker__plus text-grey-dark" href="#" type="button">
# <i class="fa fa-plus"></i>
# </button>
# </div>
# <button class="product-box__tocart text-white bg-secondary px-2 md:w-full" name="refresh_submit" title="В корзину" type="submit" value=""><i class="fa fa-shopping-cart"></i><span class="text-base"> добавлено в  корзину.</span></button>
# </form>
# </div>
# </div>
# </div>
# <div class="product-box-container flex col-sm-4 col-lg-3 col-xs-12 mb-4">
# <div class="bg-white product-box flex">
# <div class="product-box__image text-center p-0 md:p-2">
# <a href="/online-kaufen/omep-hexal-20-mg-magensaftresistente-hartkapseln-10070208" title="Omep Hexal 20 mg magensaftresistente Hartkapseln">
# <img alt="Omep Hexal 20 mg magensaftresistente Hartkapseln" src="/documents/products/Listenansicht/1010112670.jpg" style="margin: auto" title="Omep Hexal 20 mg magensaftresistente Hartkapseln">
# </img></a>
# <div class="bg-primary text-white flex flex-col justify-between text-center leading-none absolute pin-t z-1 rounded-full mt-3 pin-r w-24 h-24 text-base">
# <span class="my-auto">-50 %<sup>1</sup></span>
# </div>
# </div>
# <div class="product-box__meta">
# <div class="productrating">
# </div>
# <h4 class="product-box__title mt-0 mb-2"><a class="text-grey-darker h4 text-base mb-0" href="/online-kaufen/omep-hexal-20-mg-magensaftresistente-hartkapseln-10070208" title="Omep Hexal 20 mg magensaftresistente Hartkapseln">Omep Hexal 20 mg magensaftresistente Hartkapseln</a></h4>
# <div class="list-meta">
# <div>
# <span class="font-sari">Форма выпуска: Magensaftresistente Hartkapseln</span>
# </div>
# <div>
# <span class="font-sari">Содержание:</span> 14 St
#                                     </div>
# <div>
# <span class="font-sari">Фармацевтический номер:</span> 10070208
#                                 </div>
# <div>
# <span class="font-sari">Производитель:</span> Hexal AG
#                                                                     </div>
# ...
# <ul class=""><li><a href="/online-shop/kosmetik/gesicht/24-h-pflege" title="Уход 24 часа">Уход 24 часа</a></li><li><a href="/online-shop/kosmetik/gesicht/anti-age-pflege" title="Антивозрастной уход">Антивозрастной уход</a></li><li><a href="/online-shop/kosmetik/gesicht/augenpflege" title="Уход за глазами">Уход за глазами</a></li><li><a href="/online-shop/kosmetik/gesicht/lippenpflege" title="Средства для ухода за губами">Средства для ухода за губами</a></li><li><a href="/online-shop/kosmetik/gesicht/masken-co" title="Маски и прочее">Маски и прочее</a></li><li><a href="/online-shop/kosmetik/gesicht/nachtpflege" title="Ночной уход">Ночной уход</a></li><li><a href="/online-shop/kosmetik/gesicht/pigmentpflege" title="Средства по уходу при пигментации">Средства по уходу при пигментации</a></li><li><a href="/online-shop/kosmetik/gesicht/reinigung" title="Очищение">Очищение</a></li><li><a href="/online-shop/kosmetik/gesicht/tagespflege" title="Уход за престарелами">Уход за престарелами</a></li></ul>
# </ul></li><li><a href="/online-shop/kosmetik
#             });
#         </script>
# <script type="text/javascript">window.shoptexts = {'search': {'placeholder': 'На латинице: название, PZN или дейст. вещество','noResult': 'Нет результатов','products': 'Рекомендованные товары','goToAll': 'Показать все результаты','manufacturer': 'Производитель','productGroups': 'Категории','suggestions': 'Предложения','redirects': 'Переадрессация','searching': '""Поиск результатов..."','minimumCharactersPre': 'Поиск  должен как минимум','minimumCharactersAfter': 'содержать знаков.'},'cartSummary' : {'empty' : 'Корзина пуста.','total' : 'Промежуточная сумма','priceInfo' : 'Цены Вкл. НДС" при необходимости включая стоимость доставки','addedToCart': 'добавлено в  корзину.','toCheckout': 'К оплате','shippingHeadline': 'Не хватает до бесплатной доставки','edit': 'К корзине','continueShopping': 'Продолжить покупки','crossSellingHeadline': 'Любимые продукты','crossSellingGoToProduct': 'К товару',},'offcanvas': {'continueShopping': 'Продолжить покупки'},'modal': {'close' : 'Закрыть'},'notepad': {'add_to_notepad': 'В Списке отложенных товаров','remove_from_notepad': 'Vom Merkzettel entfernen'},'revocation': {'cancel_all': 'Я хочу отказаться от всего заказа','cancel_some': 'Я хочу отказаться от следующих товаров в заказе','product_number': 'Товар №','amount': 'Количество','add_product': 'Добавить товар'}}</script>
# <script src="/assets/master/tmp/main.min.2a4ef640.js" type="text/javascript"></script>
# <script>
#         let promoBanner = document.querySelector(".promotion-banner");
#         let promoButtonClose = document.querySelector(".promotion-close");
#         if (promoBanner) {
#             let userClass = promoBanner.classList[0];
#             let cookieName = 'promoBannerClosed' + userClass;
#             let userCookie = getCookie(cookieName);
#             if(userCookie != 'closed'){
#                 promoBanner.classList.remove("hide");
#             }
#             promoButtonClose.addEventListener('click', function(e){
#                 e.preventDefault();
#                 setCookie(cookieName, 'closed', 90)
#                 promoBanner.classList.add("hide");
#             });
#         }
#
#         function getCookie(cname) {
#             var name = cname + "=";
#             var decodedCookie = decodeURIComponent(document.cookie);
#             var ca = decodedCookie.split(';');
#             for(var i = 0; i <ca.length; i++) {
#                 var c = ca[i];
#                 while (c.charAt(0) == ' ') {
#                     c = c.substring(1);
#                 }
#                 if (c.indexOf(name) == 0) {
#                     return c.substring(name.length, c.length);
#                 }
#             }
#             return "";
#         }
#
#         function setCookie(cname, cvalue, exdays) {
#             var d = new Date();
#             d.setTime(d.getTime() + (exdays*24*60*60*1000));
#             var expires = "expires="+ d.toUTCString();
#             document.cookie = cname + "=" + cvalue + ";" + expires + ";path=/";
#         }
#     </script>
# <noscript>
# <div id="javaScriptWarning" style="width: 100%; position:fixed; bottom: 0; left:0;z-index:1000;">
# <div style="background-color: #222;opacity:0.9;color: #FFFFFF;font-size: 13px;margin: 0 auto;padding: 8px;text-align: center;line-height:18px;">
#                             Javascript не активен. <br> Пожалуйста, активируйте Javascript в браузере, иначе будут доступны не все функции сайта.
#                         </br></div>
# </div>
# </noscript>
# <script>(function (init)
# {
#     var root = document.getElementsByTagName('html')[0];
#     root.setAttribute('debug-cms', true);
#     root.setAttribute('debug-shoptext', true);
#
#         })();</script><div id="status200"></div></body>
# </html>

# %%
# Парсинг названия товара
name = soup.find('h1', ('class', 'h2 mt-0 sm:mb-6')).text
name
# Out:
# 'Allegra Allergietabletten 20 mg 20\xa0St'

# %%
import re

# %%
form = soup.find('div', text=re.compile('Форма выпуска:'))
# Out:
# <ipython-input-50-2f7d2013aff9>:1: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   form = soup.find('div', text=re.compile('Форма выпуска:'))

# %%
form.get_text(strip=True)[15:]
# Out:
# 'Tabletten'

# %%
# Парсинг формы выпуска
form = soup.find('div', text=re.compile('Форма выпуска:')).get_text(strip=True)[15:]
form
# Out:
# <ipython-input-52-edb702dab6da>:2: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   form = soup.find('div', text=re.compile('Форма выпуска:')).get_text(strip=True)[15:]
# 'Tabletten'

# %%
# Парсинг содержания
content = soup.find('div', text=re.compile('Содержание:')).get_text(strip=True)
content
# Out:
# <ipython-input-53-30b04ad4011c>:2: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   content = soup.find('div', text=re.compile('Содержание:')).get_text(strip=True)
# 'Содержание:\n    20\xa0St'

# %%
content = int(re.findall(r'\d+', content)[0])
content
# Out:
# 20

# %%
# Парсинг производителя
manufacturer = soup.find('div', text=re.compile('Производитель:')).get_text(strip=True)[15:]
manufacturer
# Out:
# <ipython-input-55-5e06e59eb78c>:2: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   manufacturer = soup.find('div', text=re.compile('Производитель:')).get_text(strip=True)[15:]
# 'A. Nattermann & Cie GmbH'

# %%
# Парсинг цены товара
price = soup.find('p',('class','price-details text-grey-darker text-4xl font-sans font-bold mb-0')).find('span').text
price
# Out:
# '7,79\xa0€'

# %%
type(price)
# Out:
# str

# %%
price = price.replace(',', '.')

# %%
price = re.sub(r'[^\d.]+', '', price)
price
# Out:
# '7.79'

# %%
price = soup.find('p',('class','price-details text-grey-darker text-4xl font-sans font-bold mb-0')).find('span').text
price = price.replace(',', '.')
price = re.sub(r'[^\d.]+', '', price)
float(price)
# Out:
# 7.79

# %%
float(price)
# Out:
# 7.79

# %% [markdown]
# ### Объединяем все вместе - скрейпинг и парсинг информации о всех товарах одной страницы

# %%
# Пустые списки, которые будут содержать соответствующие данные: название, цена, форма выпуска, содержание, производитель
name =[]
price =[]
form = []
content =[]
manufacturer =[]

# %%
# Создание пустого словаря, который будет содержать все получаемые данные
output ={}

# %%
# Цикл по списку ссылок на товары
for i in url_joined:
  response = requests.get(i)
  soup = BeautifulSoup(response.content, 'html.parser')

# Парсинг названия товара. Обработка исключения: добавляем пустую строку.
  try:
    name.append(soup.find('h1', ('class', 'h2 mt-0 sm:mb-6')).text)
  except:
    name.append('')

# Парсинг цены товара.
  try:
    p = soup.find('p',('class','price-details text-grey-darker text-4xl font-sans font-bold mb-0')).find('span').text
    p = p.replace(',', '.')
    p = float(re.sub(r'[^\d.]+', '', p))
    price.append(p)
  except:
    price.append('')

# Парсинг формы выпуска товара.
  try:
    form.append(soup.find('div', text=re.compile('Форма выпуска:')).get_text(strip=True)[15:])
  except:
    form.append('')

# Парсинг содержания (веса) товара.
  try:
    cont = soup.find('div', text=re.compile('Содержание:')).get_text(strip=True)
    cont = int(re.findall(r'\d+', cont)[0])
    content.append(cont)
  except:
    content.append('')

# Парсинг производителя товара.
  try:
    manufacturer.append(soup.find('div', text=re.compile('Производитель:')).get_text(strip=True)[15:])
  except:
    manufacturer.append('')

# Записываем данные в словарь
  output = {'Name' : name, 'Price' : price, 'Form' : form, 'Content' : content, 'Manufacturer' : manufacturer}
# Out:
# <ipython-input-64-4d5d78ffc18e>:23: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   form.append(soup.find('div', text=re.compile('Форма выпуска:')).get_text(strip=True)[15:])
# <ipython-input-64-4d5d78ffc18e>:29: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   cont = soup.find('div', text=re.compile('Содержание:')).get_text(strip=True)
# <ipython-input-64-4d5d78ffc18e>:37: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   manufacturer.append(soup.find('div', text=re.compile('Производитель:')).get_text(strip=True)[15:])

# %%
output
# Out:
# {'Name': ['Allegra Allergietabletten 20 mg 20\xa0St',
#   'Allergodil akut forte 1,5 mg/ml Nasenspray Lösung 10\xa0ml',
#   'Vividrin Azelastin EDO, bei Heuschnupfen und Allergien 20X0.6\xa0ml',
#   'Desloratadin-Adgc 5 mg Filmtabletten 100\xa0St',
#   'Desloratadin-Adgc 5 mg Filmtabletten 50\xa0St',
#   'Desloratadin-Adgc 5 mg Filmtabletten 20\xa0St',
#   'Abtei Meersalz Nasen Spray 20\xa0ml',
#   'Desloratadin Heumann 5 mg Filmtabletten 100\xa0St',
#   'Desloratadin Heumann 5 mg Filmtabletten 50\xa0St',
#   'Desloratadin Heumann 5 mg Filmtabletten 20\xa0St',
#   'Desloratadin Heumann 5 mg Filmtabletten 10\xa0St',
#   'Allvent intens Kapseln 60\xa0St',
#   'Levocetirizin Micro Labs 5 mg Filmtabletten 100\xa0St',
#   'Levocetirizin Micro Labs 5 mg Filmtabletten 50\xa0St',
#   'Levocetirizin Micro Labs 5 mg Filmtabletten 20\xa0St',
#   'Mometason beta Heuschnupfenspray 18\xa0g',
#   'Mometason beta Heuschnupfenspray 10\xa0g',
#   'Desloratadin Glenmark 5 mg Tabletten 7\xa0St',
#   'Desloratadin Stada 5 mg Filmtabletten 100\xa0St',
#   'Desloratadin Stada 5 mg Filmtabletten 50\xa0St',
#   'Desloratadin Stada 5 mg Filmtabletten 20\xa0St',
#   'Levoceti-AbZ 5 mg Filmtabletten bei Allergien 50\xa0St',
#   'Levoceti-AbZ 5 mg Filmtabletten bei Allergien 20\xa0St',
#   'Levoceti-AbZ 5 mg Filmtabletten bei Allergien 100\xa0St'],
#  'Price': [7.79,
#   9.69,
#   6.99,
#   15.56,
#   8.32,
#   3.95,
#   4.3,
#   39.45,
#   22.06,
#   9.97,
#   5.75,
#   42.5,
#   26.12,
#   14.4,
#   6.62,
#   13.9,
#   8.76,
#   4.26,
#   18.99,
#   9.99,
#   10.85,
#   16.26,
#   7.66,
#   14.49],
#  'Form': ['Tabletten',
#   'Nasenspray',
#   'Augentropfen',
#   'Filmtabletten',
#   'Filmtabletten',
#   'Filmtabletten',
#   'Nasenspray',
#   'Filmtabletten',
#   'Filmtabletten',
#   'Filmtabletten',
#   'Filmtabletten',
#   'Kapseln',
#   'Filmtabletten',
#   'Filmtabletten',
#   'Filmtabletten',
#   'Nasenspray',
#   'Nasenspray',
#   'Tabletten',
#   'Filmtabletten',
#   'Filmtabletten',
#   'Filmtabletten',
#   'Filmtabletten',
#   'Filmtabletten',
#   'Filmtabletten'],
#  'Content': [20,
#   10,
#   20,
#   100,
#   50,
#   20,
#   20,
#   100,
#   50,
#   20,
#   10,
#   60,
#   100,
#   50,
#   20,
#   18,
#   10,
#   7,
#   100,
#   50,
#   20,
#   50,
#   20,
#   100],
#  'Manufacturer': ['A. Nattermann & Cie GmbH',
#   'Viatris Healthcare GmbH',
#   'Dr. Gerhard Mann Chem.-pharm.Fabrik GmbH',
#   'Zentiva Pharma GmbH',
#   'Zentiva Pharma GmbH',
#   'Zentiva Pharma GmbH',
#   'Perrigo Deutschland GmbH',
#   'HEUMANN PHARMA GmbH & Co. Generica KG',
#   'HEUMANN PHARMA GmbH & Co. Generica KG',
#   'HEUMANN PHARMA GmbH & Co. Generica KG',
#   'HEUMANN PHARMA GmbH & Co. Generica KG',
#   'WEBER & WEBER GmbH',
#   'Micro Labs GmbH',
#   'Micro Labs GmbH',
#   'Micro Labs GmbH',
#   'betapharm Arzneimittel GmbH',
#   'betapharm Arzneimittel GmbH',
#   'Glenmark Arzneimittel GmbH',
#   'STADA Consumer Health Deutschland GmbH',
#   'STADA Consumer Health Deutschland GmbH',
#   'STADA Consumer Health Deutschland GmbH',
#   'AbZ Pharma GmbH',
#   'AbZ Pharma GmbH',
#   'AbZ Pharma GmbH']}

# %%
# Создание pandas dataframe
df = pd.DataFrame(output)

# %%
df
# Out:
#                                                  Name  Price           Form  \
# 0               Allegra Allergietabletten 20 mg 20 St   7.79      Tabletten
# 1   Allergodil akut forte 1,5 mg/ml Nasenspray Lös...   9.69     Nasenspray
# 2   Vividrin Azelastin EDO, bei Heuschnupfen und A...   6.99   Augentropfen
# 3         Desloratadin-Adgc 5 mg Filmtabletten 100 St  15.56  Filmtabletten
# 4          Desloratadin-Adgc 5 mg Filmtabletten 50 St   8.32  Filmtabletten
# 5          Desloratadin-Adgc 5 mg Filmtabletten 20 St   3.95  Filmtabletten
# 6                    Abtei Meersalz Nasen Spray 20 ml   4.30     Nasenspray
# 7      Desloratadin Heumann 5 mg Filmtabletten 100 St  39.45  Filmtabletten
# 8       Desloratadin Heumann 5 mg Filmtabletten 50 St  22.06  Filmtabletten
# 9       Desloratadin Heumann 5 mg Filmtabletten 20 St   9.97  Filmtabletten
# 10      Desloratadin Heumann 5 mg Filmtabletten 10 St   5.75  Filmtabletten
# 11                       Allvent intens Kapseln 60 St  42.50        Kapseln
# 12  Levocetirizin Micro Labs 5 mg Filmtabletten 10...  26.12  Filmtabletten
# 13  Levocetirizin Micro Labs 5 mg Filmtabletten 50 St  14.40  Filmtabletten
# 14  Levocetirizin Micro Labs 5 mg Filmtabletten 20 St   6.62  Filmtabletten
# 15              Mometason beta Heuschnupfenspray 18 g  13.90     Nasenspray
# 16              Mometason beta Heuschnupfenspray 10 g   8.76     Nasenspray
# 17          Desloratadin Glenmark 5 mg Tabletten 7 St   4.26      Tabletten
# 18       Desloratadin Stada 5 mg Filmtabletten 100 St  18.99  Filmtabletten
# 19        Desloratadin Stada 5 mg Filmtabletten 50 St   9.99  Filmtabletten
# 20        Desloratadin Stada 5 mg Filmtabletten 20 St  10.85  Filmtabletten
# 21  Levoceti-AbZ 5 mg Filmtabletten bei Allergien ...  16.26  Filmtabletten
# 22  Levoceti-AbZ 5 mg Filmtabletten bei Allergien ...   7.66  Filmtabletten
# 23  Levoceti-AbZ 5 mg Filmtabletten bei Allergien ...  14.49  Filmtabletten
#
#     Content                              Manufacturer
# 0        20                  A. Nattermann & Cie GmbH
# 1        10                   Viatris Healthcare GmbH
# 2        20  Dr. Gerhard Mann Chem.-pharm.Fabrik GmbH
# 3       100                       Zentiva Pharma GmbH
# 4        50                       Zentiva Pharma GmbH
# 5        20                       Zentiva Pharma GmbH
# 6        20                  Perrigo Deutschland GmbH
# 7       100     HEUMANN PHARMA GmbH & Co. Generica KG
# 8        50     HEUMANN PHARMA GmbH & Co. Generica KG
# 9        20     HEUMANN PHARMA GmbH & Co. Generica KG
# 10       10     HEUMANN PHARMA GmbH & Co. Generica KG
# 11       60                        WEBER & WEBER GmbH
# 12      100                           Micro Labs GmbH
# 13       50                           Micro Labs GmbH
# 14       20                           Micro Labs GmbH
# 15       18               betapharm Arzneimittel GmbH
# 16       10               betapharm Arzneimittel GmbH
# 17        7                Glenmark Arzneimittel GmbH
# 18      100    STADA Consumer Health Deutschland GmbH
# 19       50    STADA Consumer Health Deutschland GmbH
# 20       20    STADA Consumer Health Deutschland GmbH
# 21       50                           AbZ Pharma GmbH
# 22       20                           AbZ Pharma GmbH
# 23      100                           AbZ Pharma GmbH

# %% [markdown]
# ## Скрейпинг нескольких страниц

# %%
name =[]
price =[]
form = []
content =[]
manufacturer =[]
output = {}

url_1 = 'https://apteka.de'
url = "https://apteka.de/online-shop/allergie-heuschnupfen"

while True:

  page = requests.get(url)
  soup = BeautifulSoup(page.content, 'html.parser')
  next_page_link = soup.find('a', ('class', 'arrow next'))
  result = soup.find_all('div', ('class','product-box-container'))

  url_2 = []
  for i in result:
    for link in i.find_all('div', ('class','product-box__image')):
      url_2.append(link.find('a').get('href'))

  url_joined = []

  for link in url_2:
    url_joined.append(urllib.parse.urljoin(url_1, link))

  for i in url_joined:
    response = requests.get(i)

    soup = BeautifulSoup(response.content, 'html.parser')

    # Парсинг названия товара. Обработка исключения: добавляем пустую строку.
    try:
      name.append(soup.find('h1', ('class', 'h2 mt-0 sm:mb-6')).text)
    except:
      name.append('')

    # Парсинг цены товара.
    try:
      p = soup.find('p',('class','price-details text-grey-darker text-4xl font-sans font-bold mb-0')).find('span').text
      p = p.replace(',', '.')
      p = float(re.sub(r'[^\d.]+', '', p))
      price.append(p)
    except:
      price.append('')

    # Парсинг формы выпуска товара.
    try:
      form.append(soup.find('div', text=re.compile('Форма выпуска:')).get_text(strip=True)[15:])
    except:
      form.append('')

    # Парсинг содержания (веса) товара.
    try:
      cont = soup.find('div', text=re.compile('Содержание:')).get_text(strip=True)
      cont = int(re.findall(r'\d+', cont)[0])
      content.append(cont)
    except:
      content.append('')

    # Парсинг производителя товара.
    try:
      manufacturer.append(soup.find('div', text=re.compile('Производитель:')).get_text(strip=True)[15:])
    except:
      manufacturer.append('')

    output = {'Name' : name, 'Price' : price, 'Form' : form, 'Content' : content, 'Manufacturer' : manufacturer}

  if not next_page_link:
    break

  url = url_1 + next_page_link['href']
# Out:
# <ipython-input-69-ad3ad0ca96e4>:50: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   form.append(soup.find('div', text=re.compile('Форма выпуска:')).get_text(strip=True)[15:])
# <ipython-input-69-ad3ad0ca96e4>:56: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   cont = soup.find('div', text=re.compile('Содержание:')).get_text(strip=True)
# <ipython-input-69-ad3ad0ca96e4>:64: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   manufacturer.append(soup.find('div', text=re.compile('Производитель:')).get_text(strip=True)[15:])

# %%
df = pd.DataFrame(output)
df
# Out:
#                                                   Name  Price  \
# 0                Allegra Allergietabletten 20 mg 20 St   7.79
# 1    Allergodil akut forte 1,5 mg/ml Nasenspray Lös...   9.69
# 2    Vividrin Azelastin EDO, bei Heuschnupfen und A...   6.99
# 3          Desloratadin-Adgc 5 mg Filmtabletten 100 St  15.56
# 4           Desloratadin-Adgc 5 mg Filmtabletten 50 St   8.32
# ..                                                 ...    ...
# 139      Livocab direkt Augentropfen bei Allergie 4 ml   8.99
# 140        Livocab direkt Nasenspray bei Allergie 5 ml   6.49
# 141                       Allergodil Augentropfen 6 ml  12.97
# 142                   Cetirizin AL 1 mg/ml Sirup 75 ml   6.40
# 143                 Cetirizin AL 1 mg/ml Sirup 2X75 ml  11.40
#
#                      Form  Content                              Manufacturer
# 0               Tabletten       20                  A. Nattermann & Cie GmbH
# 1              Nasenspray       10                   Viatris Healthcare GmbH
# 2            Augentropfen       20  Dr. Gerhard Mann Chem.-pharm.Fabrik GmbH
# 3           Filmtabletten      100                       Zentiva Pharma GmbH
# 4           Filmtabletten       50                       Zentiva Pharma GmbH
# ..                    ...      ...                                       ...
# 139          Augentropfen        4              Johnson & Johnson GmbH (OTC)
# 140            Nasenspray        5              Johnson & Johnson GmbH (OTC)
# 141          Augentropfen        6                   Viatris Healthcare GmbH
# 142  Lösung zum Einnehmen       75                         ALIUD Pharma GmbH
# 143  Lösung zum Einnehmen        2                         ALIUD Pharma GmbH
#
# [144 rows x 5 columns]

# %%
df.to_csv('remedies.csv')
